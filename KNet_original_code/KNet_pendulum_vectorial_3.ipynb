# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/KalmanNet_Visual/KalmanNet_VO/KNet_original_code
# Out:
# /content/drive/MyDrive/KalmanNet_Visual/KalmanNet_VO/KNet_original_code

# %%
import torch
from KalmanNet_sysmdl import SystemModel
from Pipeline_EKF_original_mod import Pipeline_EKF
from KalmanNet_nn import KalmanNetNN
from model import f, h_full, h_partial, h_nonlinear
import datetime
from datetime import date
import numpy as np
import os
import matplotlib.pyplot as plt
from torch.utils.tensorboard import SummaryWriter

if torch.cuda.is_available():
   dev = torch.device("cuda:0")  # you can continue going on here, like cuda:1 cuda:2....etc.
   torch.set_default_tensor_type('torch.cuda.FloatTensor')
   print("Running on the GPU")
else:
   dev = torch.device("cpu")
   print("Running on the CPU")

ROOT_PATH = "/content/drive/MyDrive/KalmanNet_Visual/KalmanNet_VO/"
# Out:
# Running on the CPU
# using CPU!
# Running on the CPU
# Running on the CPU

# %%
def seed_everything(seed: int):
    import random, os
    import numpy as np
    import torch
    
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

# %%
#seed_everything(43)
###CONSTANT Q2 EXPERIMENT###
weight_theta_loss = 1
weight_omega_loss = 0 

T = 50
T_test = 400
T_cv = 400
samples_train = 3000 #size of training set
samples_cv = 10 #size of validation set
step=8

warm_up_T = 50

warm_up_T_cv = 50
BATCH_SIZE_warm = 2
EPOCHS_warm = 0

EPOCHS = 1000
BATCH_SIZE = 10
LR = 1e-4
WD = 1e-4



modelKnow = "partial"
#writer = SummaryWriter(log_dir=ROOT_PATH+"KalmanNet", comment=f"EPOCHS_{EPOCHS}_LR_{LR}_BSIZ_{BATCH_SIZE}_WD_{WD}")




linewidth=0.5
markersize=2
title_size=7
ax_label_size=7

m1x_0 = torch.Tensor([[0.0], [0.0]]).to(dev)
m2x_0 = torch.eye(2)


r2s = [10, 2, 1, 0.5, 0.1, 0.01, 0.001, 0.0001]
r2s = [0.5, 0.1, 0.01, 0.001, 0.0001]
r2s = [10]
q2s = [0, -10, -20]
q2s = [0]
q2s = list(map(lambda x: 10**(x/10), q2s))
v = 0

for q2 in q2s:
  input_ = np.load(ROOT_PATH+f"Datasets/Pendulum/decimated_clean_data/pendulum_decimated_q2_{q2:.0e}_v_{v}.npz")
  target_ = input_
  for r2 in r2s:
    print(f"Evaluation for r2 {r2}, q2 {q2} \n")
    
    r = np.sqrt(r2)
    q = np.sqrt(q2)

    """
    if modelKnow == "partial":
      train_input = torch.from_numpy(input_["training_set"][:samples_train, 0:1, ::step]).to(dev) + torch.randn(input_["training_set"][:samples_train, 0:1, ::step].shape) * r
      train_target = torch.from_numpy(target_["training_set"][:samples_train, :, ::step]).float().to(dev)
      cv_input = torch.from_numpy(input_["validation_set"][:samples_cv, 0:1, ::step]).to(dev) + torch.randn(input_["validation_set"][:samples_cv, 0:1, ::step].shape) * r
      cv_target = torch.from_numpy(target_["validation_set"][:samples_cv, :, ::step]).float().to(dev)
       
      train_input_warm_up = torch.from_numpy(input_["training_set"][2000:2200, 0:1, ::step]).to(dev) + torch.randn(input_["training_set"][2000:2200, 0:1, ::step].shape) * r
      train_target_warm_up = torch.from_numpy(target_["training_set"][2000:2200, :, ::step]).float().to(dev)
      cv_input_warm_up = torch.from_numpy(input_["validation_set"][500:550, 0:1, ::step]).to(dev) + torch.randn(input_["validation_set"][500:550, 0:1, ::step].shape) * r
      cv_target_warm_up = torch.from_numpy(target_["validation_set"][500:550, :, ::step]).float().to(dev)

      test_input = torch.from_numpy(input_["test_set"][:, 0:1, ::step]).to(dev) + torch.randn(input_["test_set"][:, 0:1, ::step].shape) * r
      test_target = torch.from_numpy(target_["test_set"][:, :, ::step]).float().to(dev)

      h = h_partial
      m = 2  # DIMENSION OF STATE
      n = 1
      """
    if modelKnow == "partial":
      train_input = torch.from_numpy(input_["training_set"][:samples_train, 0:1, :T]).to(dev) + torch.randn(input_["training_set"][:samples_train, 0:1, :T].shape) * r
      train_target = torch.from_numpy(target_["training_set"][:samples_train, :, :T]).float().to(dev)
      cv_input = torch.from_numpy(input_["validation_set"][:samples_cv, 0:1, :T_cv]).to(dev) + torch.randn(input_["validation_set"][:samples_cv, 0:1, :T_cv].shape) * r
      cv_target = torch.from_numpy(target_["validation_set"][:samples_cv, :, :T_cv]).float().to(dev)
      
      #train_input_warm_up = torch.from_numpy(input_["training_set"][2000:2200, 0:1, :warm_up_T]).to(dev) + torch.randn(input_["training_set"][2000:2200, 0:1, :warm_up_T].shape) * r
      #train_target_warm_up = torch.from_numpy(target_["training_set"][2000:2200, :, :warm_up_T]).float().to(dev)
      #cv_input_warm_up = torch.from_numpy(input_["validation_set"][500:550, 0:1, :warm_up_T_cv]).to(dev) + torch.randn(input_["validation_set"][500:550, 0:1, :warm_up_T_cv].shape) * r
      #cv_target_warm_up = torch.from_numpy(target_["validation_set"][500:550, :, ::warm_up_T_cv]).float().to(dev)

      test_input = torch.from_numpy(input_["test_set"][:, 0:1, :T_test]).to(dev) + torch.randn(input_["test_set"][:, 0:1, :T_test].shape) * r
      test_target = torch.from_numpy(target_["test_set"][:, :, :T_test]).float().to(dev)

      h = h_partial
      m = 2  # DIMENSION OF STATE
      n = 1

    train_input = train_input.float().to(dev)
    #cv_input = cv_input.float().to(dev)
    #train_input_warm_up = train_input_warm_up.float().to(dev)
    #cv_input_warm_up = cv_input_warm_up.float().to(dev)
    test_input = test_input.float().to(dev)
    cv_input = cv_input.float().to(dev)


  
    print(f"Beginning with q2 {q2}, r2 {r2}.")
    today = date.today()
    now = datetime.datetime.now()
    strToday = today.strftime("%m.%d.%y")
    strNow = now.strftime("%H:%M:%S")
    strTime = strToday + "_" + strNow
    print("Current Time =", strTime)


    Q_true = q2 * torch.eye(m)
    R_true = r2 * torch.eye(n)

    #WARM UP PHASE
    print("WARM UP PHASE")
    #sys_model = SystemModel(f, Q_true, h, R_true, warm_up_T, T_test, warm_up_T_cv)
    sys_model = SystemModel(f, Q_true, h, R_true, T, T_test, T_cv)

    modelFolder = ROOT_PATH +f"Simulations_results/Pendulum/KalmanNet/constant_q2_experiment/tuning_experiments/experiment_T{T}_Tcv{T_cv}_Ttest{T_test}_B{BATCH_SIZE}_LR{LR}_WD{WD}_NT{samples_train}_NCV{samples_cv}_wt_{weight_theta_loss}_wo_{weight_omega_loss}/models"
    folder = ROOT_PATH + f"Simulations_results/Pendulum/KalmanNet/constant_q2_experiment/tuning_experiments/experiment_T{T}_Tcv{T_cv}_Ttest{T_test}_B{BATCH_SIZE}_LR{LR}_WD{WD}_NT{samples_train}_NCV{samples_cv}_wt_{weight_theta_loss}_wo_{weight_omega_loss}/losses"
    os.makedirs(modelFolder+"/", exist_ok=True)
    os.makedirs(folder+"/", exist_ok=True)
    KNet_Pipeline = Pipeline_EKF(strTime, modelFolder, f"KNet")
    KNet_Pipeline.setssModel(sys_model)
    
    KNet_model = KalmanNetNN()
    KNet_model.Build(sys_model)
    KNet_Pipeline.setModel(KNet_model)
    #KNet_Pipeline.setTrainingParams(n_Epochs=EPOCHS_warm, n_Batch=BATCH_SIZE_warm, learningRate=LR, weightDecay=WD)
    #KNet_Pipeline.NNTrain(train_input_warm_up, train_target_warm_up, cv_input_warm_up, cv_target_warm_up, save_model_wrt=0)
    print("ACTUAL TRAINING PHASE")
    #TRAINING PHASE
    
    #KNet_Pipeline.setssModel(sys_model)


    KNet_Pipeline.setTrainingParams(n_Epochs=EPOCHS, n_Batch=BATCH_SIZE, learningRate=LR, weightDecay=WD)
    KNet_Pipeline.NNTrain(train_input, train_target, cv_input, cv_target, weight_theta_loss=weight_theta_loss, weight_omega_loss=weight_omega_loss, save_model_wrt=0)
    
    cv_loss = KNet_Pipeline.MSE_cv_linear_epoch.detach().cpu().numpy()
    training_loss = KNet_Pipeline.MSE_train_linear_epoch.detach().cpu().numpy()
    

    np.savez(folder + f"/training_loss.npz", training_loss=training_loss, validation_loss=cv_loss, batch_size=BATCH_SIZE, epochs=EPOCHS, learning_rate=LR, weight_decay= WD)

    
    [MSE_test_linear_arr_total, MSE_test_dB_avg_total, MSE_test_dB_std_total,
    MSE_test_linear_arr_theta, MSE_test_dB_avg_theta, MSE_test_dB_std_theta,
    MSE_test_linear_arr_omega, MSE_test_dB_avg_omega, MSE_test_dB_std_omega, x_out_array] = KNet_Pipeline.NNTest(test_input, test_target)
    KNet_Pipeline.PlotTrain_KF()
    KNet_Pipeline.save()
    
    np.savez(folder+f"/test_loss.npz", MSE_linear_arr_total=MSE_test_linear_arr_total.cpu(), 
            MSE_std_total=MSE_test_dB_std_total.cpu(), MSE_db_avg_total=MSE_test_dB_avg_total.cpu(),
            MSE_linear_arr_theta=MSE_test_linear_arr_theta.cpu(), MSE_std_theta=MSE_test_dB_std_theta.cpu(), 
            MSE_db_avg_theta=MSE_test_dB_avg_theta.cpu(), MSE_linear_arr_omega=MSE_test_linear_arr_omega.cpu(), 
            MSE_std_omega=MSE_test_dB_std_omega.cpu(), MSE_db_avg_omega=MSE_test_dB_avg_omega.cpu(), 
            test_out=x_out_array.cpu(), batch_size=BATCH_SIZE, epochs=EPOCHS, learning_rate=LR, weight_decay=WD)
# Out:
# Evaluation for r2 10, q2 1.0
#
# Beginning with q2 1.0, r2 10.
# Current Time = 06.15.22_15:37:44
# WARM UP PHASE
# ACTUAL TRAINING PHASE
# 0, MSE Training total/theta/omega: 17.56/17.56/26.37 [dB], MSE Validation total/theta/omega :254.04/254.04/262.48 [dB]
# Optimal idx: 0 Optimal : tensor(254.0441) [dB]
# 1, MSE Training total/theta/omega: 9.91/9.91/22.24 [dB], MSE Validation total/theta/omega :237.30/237.30/246.42 [dB]
# Optimal idx: 1 Optimal : tensor(237.3048) [dB]
# 2, MSE Training total/theta/omega: -2.97/-2.97/13.27 [dB], MSE Validation total/theta/omega :223.49/223.49/233.17 [dB]
# diff MSE Training total/theta/cv : -12.89/-12.89/-8.97 [dB], diff MSE Validation total/theta/cv: -13.816772/-13.816772/-13.249496 [dB]
# Optimal idx: 2 Optimal : tensor(223.4880) [dB]
# 3, MSE Training total/theta/omega: 5.45/5.45/20.72 [dB], MSE Validation total/theta/omega :212.11/212.11/222.25 [dB]
# diff MSE Training total/theta/cv : 8.43/8.43/7.45 [dB], diff MSE Validation total/theta/cv: -11.379410/-11.379410/-10.921417 [dB]
# Optimal idx: 3 Optimal : tensor(212.1086) [dB]
# 4, MSE Training total/theta/omega: 10.80/10.80/21.97 [dB], MSE Validation total/theta/omega :202.11/202.11/212.70 [dB]
# diff MSE Training total/theta/cv : 5.35/5.35/1.25 [dB], diff MSE Validation total/theta/cv: -9.996628/-9.996628/-9.549942 [dB]
# Optimal idx: 4 Optimal : tensor(202.1120) [dB]
# 5, MSE Training total/theta/omega: 9.76/9.76/22.96 [dB], MSE Validation total/theta/omega :191.27/191.27/202.35 [dB]
# diff MSE Training total/theta/cv : -1.04/-1.04/0.99 [dB], diff MSE Validation total/theta/cv: -10.844238/-10.844238/-10.351059 [dB]
# Optimal idx: 5 Optimal : tensor(191.2677) [dB]
# 6, MSE Training total/theta/omega: 5.57/5.57/18.43 [dB], MSE Validation total/theta/omega :179.83/179.83/191.44 [dB]
# diff MSE Training total/theta/cv : -4.19/-4.19/-4.53 [dB], diff MSE Validation total/theta/cv: -11.437332/-11.437332/-10.909454 [dB]
# Optimal idx: 6 Optimal : tensor(179.8304) [dB]
# 7, MSE Training total/theta/omega: -2.24/-2.24/15.76 [dB], MSE Validation total/theta/omega :168.41/168.41/180.57 [dB]
# diff MSE Training total/theta/cv : -7.81/-7.81/-2.68 [dB], diff MSE Validation total/theta/cv: -11.424591/-11.424591/-10.862671 [dB]
# Optimal idx: 7 Optimal : tensor(168.4058) [dB]
# 8, MSE Training total/theta/omega: -4.45/-4.45/15.25 [dB], MSE Validation total/theta/omega :157.16/157.16/169.90 [dB]
# diff MSE Training total/theta/cv : -2.20/-2.20/-0.51 [dB], diff MSE Validation total/theta/cv: -11.245544/-11.245544/-10.673447 [dB]
# Optimal idx: 8 Optimal : tensor(157.1602) [dB]
# 9, MSE Training total/theta/omega: 2.66/2.66/15.97 [dB], MSE Validation total/theta/omega :145.90/145.90/159.23 [dB]
# diff MSE Training total/theta/cv : 7.11/7.11/0.73 [dB], diff MSE Validation total/theta/cv: -11.261551/-11.261551/-10.669266 [dB]
# Optimal idx: 9 Optimal : tensor(145.8987) [dB]
# 10, MSE Training total/theta/omega: -0.23/-0.23/18.42 [dB], MSE Validation total/theta/omega :134.26/134.26/148.22 [dB]
# diff MSE Training total/theta/cv : -2.89/-2.89/2.44 [dB], diff MSE Validation total/theta/cv: -11.637634/-11.637634/-11.016190 [dB]
# Optimal idx: 10 Optimal : tensor(134.2611) [dB]
# 11, MSE Training total/theta/omega: 3.60/3.60/19.43 [dB], MSE Validation total/theta/omega :123.53/123.53/138.25 [dB]
# diff MSE Training total/theta/cv : 3.83/3.83/1.02 [dB], diff MSE Validation total/theta/cv: -10.733086/-10.733086/-9.966003 [dB]
# Optimal idx: 11 Optimal : tensor(123.5280) [dB]
# 12, MSE Training total/theta/omega: 5.19/5.19/19.48 [dB], MSE Validation total/theta/omega :112.51/112.51/128.40 [dB]
# diff MSE Training total/theta/cv : 1.59/1.59/0.05 [dB], diff MSE Validation total/theta/cv: -11.013252/-11.013252/-9.851212 [dB]
# Optimal idx: 12 Optimal : tensor(112.5147) [dB]
# 13, MSE Training total/theta/omega: -0.53/-0.53/16.26 [dB], MSE Validation total/theta/omega :96.18/96.18/115.11 [dB]
# diff MSE Training total/theta/cv : -5.72/-5.72/-3.22 [dB], diff MSE Validation total/theta/cv: -16.335373/-16.335373/-13.284081 [dB]
# Optimal idx: 13 Optimal : tensor(96.1794) [dB]
# 14, MSE Training total/theta/omega: -1.68/-1.68/15.53 [dB], MSE Validation total/theta/omega :75.82/75.82/97.03 [dB]
# diff MSE Training total/theta/cv : -1.15/-1.15/-0.72 [dB], diff MSE Validation total/theta/cv: -20.357834/-20.357834/-18.086647 [dB]
# Optimal idx: 14 Optimal : tensor(75.8215) [dB]
# 15, MSE Training total/theta/omega: -3.39/-3.39/15.93 [dB], MSE Validation total/theta/omega :66.67/66.67/85.51 [dB]
# diff MSE Training total/theta/cv : -1.71/-1.71/0.40 [dB], diff MSE Validation total/theta/cv: -9.148193/-9.148193/-11.518173 [dB]
# Optimal idx: 15 Optimal : tensor(66.6733) [dB]
# 16, MSE Training total/theta/omega: -4.77/-4.77/15.71 [dB], MSE Validation total/theta/omega :63.54/63.54/80.45 [dB]
# diff MSE Training total/theta/cv : -1.38/-1.38/-0.22 [dB], diff MSE Validation total/theta/cv: -3.132755/-3.132755/-5.059052 [dB]
# Optimal idx: 16 Optimal : tensor(63.5406) [dB]
# 17, MSE Training total/theta/omega: -1.08/-1.08/15.45 [dB], MSE Validation total/theta/omega :63.11/63.11/78.41 [dB]
# diff MSE Training total/theta/cv : 3.70/3.70/-0.26 [dB], diff MSE Validation total/theta/cv: -0.430309/-0.430309/-2.040306 [dB]
# Optimal idx: 17 Optimal : tensor(63.1103) [dB]
# 18, MSE Training total/theta/omega: -2.60/-2.60/17.76 [dB], MSE Validation total/theta/omega :62.19/62.19/77.36 [dB]
# diff MSE Training total/theta/cv : -1.52/-1.52/2.31 [dB], diff MSE Validation total/theta/cv: -0.923355/-0.923355/-1.048798 [dB]
# Optimal idx: 18 Optimal : tensor(62.1869) [dB]
# 19, MSE Training total/theta/omega: -0.01/-0.01/13.82 [dB], MSE Validation total/theta/omega :60.79/60.79/76.50 [dB]
# diff MSE Training total/theta/cv : 2.59/2.59/-3.95 [dB], diff MSE Validation total/theta/cv: -1.396976/-1.396976/-0.865959 [dB]
# Optimal idx: 19 Optimal : tensor(60.7899) [dB]
# 20, MSE Training total/theta/omega: -4.52/-4.52/11.52 [dB], MSE Validation total/theta/omega :59.01/59.01/75.39 [dB]
# diff MSE Training total/theta/cv : -4.51/-4.51/-2.30 [dB], diff MSE Validation total/theta/cv: -1.784454/-1.784454/-1.110107 [dB]
# Optimal idx: 20 Optimal : tensor(59.0055) [dB]
# 21, MSE Training total/theta/omega: 0.12/0.12/18.59 [dB], MSE Validation total/theta/omega :57.04/57.04/74.15 [dB]
# diff MSE Training total/theta/cv : 4.64/4.64/7.07 [dB], diff MSE Validation total/theta/cv: -1.964111/-1.964111/-1.236053 [dB]
# Optimal idx: 21 Optimal : tensor(57.0414) [dB]
# 22, MSE Training total/theta/omega: -1.51/-1.51/15.79 [dB], MSE Validation total/theta/omega :54.86/54.86/72.74 [dB]
# diff MSE Training total/theta/cv : -1.63/-1.63/-2.80 [dB], diff MSE Validation total/theta/cv: -2.177933/-2.177933/-1.404198 [dB]
# Optimal idx: 22 Optimal : tensor(54.8634) [dB]
# 23, MSE Training total/theta/omega: -3.59/-3.59/16.92 [dB], MSE Validation total/theta/omega :52.64/52.64/71.27 [dB]
# diff MSE Training total/theta/cv : -2.08/-2.08/1.13 [dB], diff MSE Validation total/theta/cv: -2.218658/-2.218658/-1.478165 [dB]
# Optimal idx: 23 Optimal : tensor(52.6448) [dB]
# 24, MSE Training total/theta/omega: -4.58/-4.58/14.94 [dB], MSE Validation total/theta/omega :50.39/50.39/69.75 [dB]
# diff MSE Training total/theta/cv : -0.99/-0.99/-1.97 [dB], diff MSE Validation total/theta/cv: -2.255970/-2.255970/-1.519249 [dB]
# Optimal idx: 24 Optimal : tensor(50.3888) [dB]
# 25, MSE Training total/theta/omega: -0.68/-0.68/15.72 [dB], MSE Validation total/theta/omega :48.23/48.23/68.21 [dB]
# diff MSE Training total/theta/cv : 3.90/3.90/0.78 [dB], diff MSE Validation total/theta/cv: -2.159271/-2.159271/-1.534790 [dB]
# Optimal idx: 25 Optimal : tensor(48.2295) [dB]
# 26, MSE Training total/theta/omega: 0.02/0.02/13.77 [dB], MSE Validation total/theta/omega :46.09/46.09/66.63 [dB]
# diff MSE Training total/theta/cv : 0.70/0.70/-1.95 [dB], diff MSE Validation total/theta/cv: -2.138256/-2.138256/-1.579323 [dB]
# Optimal idx: 26 Optimal : tensor(46.0913) [dB]
# 27, MSE Training total/theta/omega: -2.47/-2.47/17.61 [dB], MSE Validation total/theta/omega :44.05/44.05/65.05 [dB]
# diff MSE Training total/theta/cv : -2.49/-2.49/3.84 [dB], diff MSE Validation total/theta/cv: -2.045811/-2.045811/-1.583954 [dB]
# Optimal idx: 27 Optimal : tensor(44.0455) [dB]
# 28, MSE Training total/theta/omega: -4.37/-4.37/16.83 [dB], MSE Validation total/theta/omega :42.29/42.29/63.49 [dB]
# diff MSE Training total/theta/cv : -1.89/-1.89/-0.78 [dB], diff MSE Validation total/theta/cv: -1.755024/-1.755024/-1.562386 [dB]
# Optimal idx: 28 Optimal : tensor(42.2904) [dB]
# 29, MSE Training total/theta/omega: -1.60/-1.60/18.54 [dB], MSE Validation total/theta/omega :40.69/40.69/61.98 [dB]
# diff MSE Training total/theta/cv : 2.77/2.77/1.71 [dB], diff MSE Validation total/theta/cv: -1.599033/-1.599033/-1.510685 [dB]
# Optimal idx: 29 Optimal : tensor(40.6914) [dB]
# 30, MSE Training total/theta/omega: -5.56/-5.56/15.11 [dB], MSE Validation total/theta/omega :39.24/39.24/60.49 [dB]
# diff MSE Training total/theta/cv : -3.96/-3.96/-3.42 [dB], diff MSE Validation total/theta/cv: -1.450642/-1.450642/-1.490520 [dB]
# Optimal idx: 30 Optimal : tensor(39.2408) [dB]
# 31, MSE Training total/theta/omega: -1.92/-1.92/14.44 [dB], MSE Validation total/theta/omega :37.91/37.91/59.10 [dB]
# diff MSE Training total/theta/cv : 3.65/3.65/-0.67 [dB], diff MSE Validation total/theta/cv: -1.327969/-1.327969/-1.388725 [dB]
# Optimal idx: 31 Optimal : tensor(37.9128) [dB]
# 32, MSE Training total/theta/omega: -6.38/-6.38/11.73 [dB], MSE Validation total/theta/omega :36.63/36.63/57.75 [dB]
# diff MSE Training total/theta/cv : -4.46/-4.46/-2.72 [dB], diff MSE Validation total/theta/cv: -1.281158/-1.281158/-1.351749 [dB]
# Optimal idx: 32 Optimal : tensor(36.6316) [dB]
# 33, MSE Training total/theta/omega: -5.17/-5.17/12.34 [dB], MSE Validation total/theta/omega :35.44/35.44/56.53 [dB]
# diff MSE Training total/theta/cv : 1.21/1.21/0.62 [dB], diff MSE Validation total/theta/cv: -1.195648/-1.195648/-1.219250 [dB]
# Optimal idx: 33 Optimal : tensor(35.4360) [dB]
# 34, MSE Training total/theta/omega: -4.07/-4.07/14.74 [dB], MSE Validation total/theta/omega :34.32/34.32/55.40 [dB]
# diff MSE Training total/theta/cv : 1.10/1.10/2.39 [dB], diff MSE Validation total/theta/cv: -1.115112/-1.115112/-1.127476 [dB]
# Optimal idx: 34 Optimal : tensor(34.3209) [dB]
# 35, MSE Training total/theta/omega: -1.34/-1.34/16.54 [dB], MSE Validation total/theta/omega :33.26/33.26/54.34 [dB]
# diff MSE Training total/theta/cv : 2.73/2.73/1.80 [dB], diff MSE Validation total/theta/cv: -1.060070/-1.060070/-1.058056 [dB]
# Optimal idx: 35 Optimal : tensor(33.2608) [dB]
# 36, MSE Training total/theta/omega: -5.22/-5.22/14.94 [dB], MSE Validation total/theta/omega :32.18/32.18/53.27 [dB]
# diff MSE Training total/theta/cv : -3.88/-3.88/-1.59 [dB], diff MSE Validation total/theta/cv: -1.085442/-1.085442/-1.070133 [dB]
# Optimal idx: 36 Optimal : tensor(32.1754) [dB]
# 37, MSE Training total/theta/omega: -4.45/-4.45/15.25 [dB], MSE Validation total/theta/omega :31.12/31.12/52.22 [dB]
# diff MSE Training total/theta/cv : 0.77/0.77/0.30 [dB], diff MSE Validation total/theta/cv: -1.060101/-1.060101/-1.055428 [dB]
# Optimal idx: 37 Optimal : tensor(31.1153) [dB]
# 38, MSE Training total/theta/omega: -5.97/-5.97/15.73 [dB], MSE Validation total/theta/omega :30.10/30.10/51.24 [dB]
# diff MSE Training total/theta/cv : -1.52/-1.52/0.48 [dB], diff MSE Validation total/theta/cv: -1.012106/-1.012106/-0.975681 [dB]
# Optimal idx: 38 Optimal : tensor(30.1032) [dB]
# 39, MSE Training total/theta/omega: -4.12/-4.12/14.22 [dB], MSE Validation total/theta/omega :29.17/29.17/50.23 [dB]
# diff MSE Training total/theta/cv : 1.85/1.85/-1.51 [dB], diff MSE Validation total/theta/cv: -0.934818/-0.934818/-1.008034 [dB]
# Optimal idx: 39 Optimal : tensor(29.1683) [dB]
# 40, MSE Training total/theta/omega: -5.65/-5.65/14.78 [dB], MSE Validation total/theta/omega :28.44/28.44/49.39 [dB]
# diff MSE Training total/theta/cv : -1.54/-1.54/0.56 [dB], diff MSE Validation total/theta/cv: -0.729544/-0.729544/-0.845619 [dB]
# Optimal idx: 40 Optimal : tensor(28.4388) [dB]
# 41, MSE Training total/theta/omega: -4.89/-4.89/15.42 [dB], MSE Validation total/theta/omega :27.55/27.55/48.46 [dB]
# diff MSE Training total/theta/cv : 0.77/0.77/0.64 [dB], diff MSE Validation total/theta/cv: -0.889685/-0.889685/-0.930645 [dB]
# Optimal idx: 41 Optimal : tensor(27.5491) [dB]
# 42, MSE Training total/theta/omega: -5.96/-5.96/13.88 [dB], MSE Validation total/theta/omega :26.87/26.87/47.67 [dB]
# diff MSE Training total/theta/cv : -1.07/-1.07/-1.53 [dB], diff MSE Validation total/theta/cv: -0.681715/-0.681715/-0.788403 [dB]
# Optimal idx: 42 Optimal : tensor(26.8674) [dB]
# 43, MSE Training total/theta/omega: -6.29/-6.29/11.59 [dB], MSE Validation total/theta/omega :26.26/26.26/46.93 [dB]
# diff MSE Training total/theta/cv : -0.33/-0.33/-2.29 [dB], diff MSE Validation total/theta/cv: -0.606201/-0.606201/-0.734589 [dB]
# Optimal idx: 43 Optimal : tensor(26.2612) [dB]
# 44, MSE Training total/theta/omega: -7.95/-7.95/13.37 [dB], MSE Validation total/theta/omega :25.58/25.58/46.19 [dB]
# diff MSE Training total/theta/cv : -1.66/-1.66/1.77 [dB], diff MSE Validation total/theta/cv: -0.678942/-0.678942/-0.739655 [dB]
# Optimal idx: 44 Optimal : tensor(25.5823) [dB]
# 45, MSE Training total/theta/omega: -5.63/-5.63/14.19 [dB], MSE Validation total/theta/omega :25.01/25.01/45.45 [dB]
# diff MSE Training total/theta/cv : 2.32/2.32/0.83 [dB], diff MSE Validation total/theta/cv: -0.570105/-0.570105/-0.747204 [dB]
# Optimal idx: 45 Optimal : tensor(25.0121) [dB]
# 46, MSE Training total/theta/omega: -4.70/-4.70/13.27 [dB], MSE Validation total/theta/omega :24.44/24.44/44.77 [dB]
# diff MSE Training total/theta/cv : 0.92/0.92/-0.92 [dB], diff MSE Validation total/theta/cv: -0.574070/-0.574070/-0.678864 [dB]
# Optimal idx: 46 Optimal : tensor(24.4381) [dB]
# 47, MSE Training total/theta/omega: -3.20/-3.20/12.31 [dB], MSE Validation total/theta/omega :23.85/23.85/44.04 [dB]
# diff MSE Training total/theta/cv : 1.50/1.50/-0.97 [dB], diff MSE Validation total/theta/cv: -0.592384/-0.592384/-0.722828 [dB]
# Optimal idx: 47 Optimal : tensor(23.8457) [dB]
# 48, MSE Training total/theta/omega: -5.70/-5.70/12.58 [dB], MSE Validation total/theta/omega :23.29/23.29/43.42 [dB]
# diff MSE Training total/theta/cv : -2.50/-2.50/0.27 [dB], diff MSE Validation total/theta/cv: -0.553896/-0.553896/-0.625145 [dB]
# Optimal idx: 48 Optimal : tensor(23.2918) [dB]
# 49, MSE Training total/theta/omega: -4.22/-4.22/15.75 [dB], MSE Validation total/theta/omega :22.86/22.86/42.92 [dB]
# diff MSE Training total/theta/cv : 1.49/1.49/3.18 [dB], diff MSE Validation total/theta/cv: -0.434628/-0.434628/-0.494854 [dB]
# Optimal idx: 49 Optimal : tensor(22.8572) [dB]
# 50, MSE Training total/theta/omega: -4.37/-4.37/14.29 [dB], MSE Validation total/theta/omega :22.34/22.34/42.30 [dB]
# diff MSE Training total/theta/cv : -0.16/-0.16/-1.47 [dB], diff MSE Validation total/theta/cv: -0.519526/-0.519526/-0.619122 [dB]
# Optimal idx: 50 Optimal : tensor(22.3376) [dB]
# 51, MSE Training total/theta/omega: -2.61/-2.61/16.54 [dB], MSE Validation total/theta/omega :21.82/21.82/41.76 [dB]
# diff MSE Training total/theta/cv : 1.77/1.77/2.25 [dB], diff MSE Validation total/theta/cv: -0.518501/-0.518501/-0.540031 [dB]
# Optimal idx: 51 Optimal : tensor(21.8191) [dB]
# 52, MSE Training total/theta/omega: -5.14/-5.14/12.69 [dB], MSE Validation total/theta/omega :21.24/21.24/41.14 [dB]
# diff MSE Training total/theta/cv : -2.53/-2.53/-3.84 [dB], diff MSE Validation total/theta/cv: -0.574677/-0.574677/-0.626766 [dB]
# Optimal idx: 52 Optimal : tensor(21.2445) [dB]
# 53, MSE Training total/theta/omega: -2.80/-2.80/13.36 [dB], MSE Validation total/theta/omega :20.75/20.75/40.57 [dB]
# diff MSE Training total/theta/cv : 2.33/2.33/0.67 [dB], diff MSE Validation total/theta/cv: -0.492346/-0.492346/-0.566959 [dB]
# Optimal idx: 53 Optimal : tensor(20.7521) [dB]
# 54, MSE Training total/theta/omega: -6.27/-6.27/15.39 [dB], MSE Validation total/theta/omega :20.28/20.28/40.00 [dB]
# diff MSE Training total/theta/cv : -3.46/-3.46/2.02 [dB], diff MSE Validation total/theta/cv: -0.471525/-0.471525/-0.571468 [dB]
# Optimal idx: 54 Optimal : tensor(20.2806) [dB]
# 55, MSE Training total/theta/omega: -5.81/-5.81/14.97 [dB], MSE Validation total/theta/omega :19.79/19.79/39.44 [dB]
# diff MSE Training total/theta/cv : 0.45/0.45/-0.42 [dB], diff MSE Validation total/theta/cv: -0.486485/-0.486485/-0.561424 [dB]
# Optimal idx: 55 Optimal : tensor(19.7941) [dB]
# 56, MSE Training total/theta/omega: -6.23/-6.23/11.48 [dB], MSE Validation total/theta/omega :19.29/19.29/38.87 [dB]
# diff MSE Training total/theta/cv : -0.42/-0.42/-3.49 [dB], diff MSE Validation total/theta/cv: -0.502714/-0.502714/-0.566429 [dB]
# Optimal idx: 56 Optimal : tensor(19.2914) [dB]
# 57, MSE Training total/theta/omega: -6.13/-6.13/12.17 [dB], MSE Validation total/theta/omega :18.80/18.80/38.32 [dB]
# diff MSE Training total/theta/cv : 0.11/0.11/0.69 [dB], diff MSE Validation total/theta/cv: -0.487995/-0.487995/-0.551971 [dB]
# Optimal idx: 57 Optimal : tensor(18.8034) [dB]
# 58, MSE Training total/theta/omega: -4.76/-4.76/13.83 [dB], MSE Validation total/theta/omega :18.31/18.31/37.76 [dB]
# diff MSE Training total/theta/cv : 1.36/1.36/1.66 [dB], diff MSE Validation total/theta/cv: -0.489721/-0.489721/-0.556194 [dB]
# Optimal idx: 58 Optimal : tensor(18.3137) [dB]
# 59, MSE Training total/theta/omega: -2.19/-2.19/13.31 [dB], MSE Validation total/theta/omega :17.78/17.78/37.19 [dB]
# diff MSE Training total/theta/cv : 2.57/2.57/-0.53 [dB], diff MSE Validation total/theta/cv: -0.532879/-0.532879/-0.575455 [dB]
# Optimal idx: 59 Optimal : tensor(17.7808) [dB]
# 60, MSE Training total/theta/omega: -6.30/-6.30/12.61 [dB], MSE Validation total/theta/omega :17.16/17.16/36.45 [dB]
# diff MSE Training total/theta/cv : -4.11/-4.11/-0.70 [dB], diff MSE Validation total/theta/cv: -0.625555/-0.625555/-0.737156 [dB]
# Optimal idx: 60 Optimal : tensor(17.1552) [dB]
# 61, MSE Training total/theta/omega: -4.79/-4.79/14.89 [dB], MSE Validation total/theta/omega :16.59/16.59/35.77 [dB]
# diff MSE Training total/theta/cv : 1.51/1.51/2.28 [dB], diff MSE Validation total/theta/cv: -0.561134/-0.561134/-0.676907 [dB]
# Optimal idx: 61 Optimal : tensor(16.5941) [dB]
# 62, MSE Training total/theta/omega: -4.70/-4.70/12.81 [dB], MSE Validation total/theta/omega :16.11/16.11/35.20 [dB]
# diff MSE Training total/theta/cv : 0.09/0.09/-2.07 [dB], diff MSE Validation total/theta/cv: -0.481810/-0.481810/-0.572994 [dB]
# Optimal idx: 62 Optimal : tensor(16.1123) [dB]
# 63, MSE Training total/theta/omega: -4.66/-4.66/15.76 [dB], MSE Validation total/theta/omega :15.62/15.62/34.69 [dB]
# diff MSE Training total/theta/cv : 0.04/0.04/2.95 [dB], diff MSE Validation total/theta/cv: -0.492020/-0.492020/-0.511654 [dB]
# Optimal idx: 63 Optimal : tensor(15.6203) [dB]
# 64, MSE Training total/theta/omega: -6.33/-6.33/13.04 [dB], MSE Validation total/theta/omega :15.51/15.51/34.41 [dB]
# diff MSE Training total/theta/cv : -1.67/-1.67/-2.72 [dB], diff MSE Validation total/theta/cv: -0.106155/-0.106155/-0.275101 [dB]
# Optimal idx: 64 Optimal : tensor(15.5141) [dB]
# 65, MSE Training total/theta/omega: -2.89/-2.89/15.41 [dB], MSE Validation total/theta/omega :15.00/15.00/33.82 [dB]
# diff MSE Training total/theta/cv : 3.44/3.44/2.36 [dB], diff MSE Validation total/theta/cv: -0.515549/-0.515549/-0.592640 [dB]
# Optimal idx: 65 Optimal : tensor(14.9986) [dB]
# 66, MSE Training total/theta/omega: -1.72/-1.72/13.44 [dB], MSE Validation total/theta/omega :14.60/14.60/33.33 [dB]
# diff MSE Training total/theta/cv : 1.16/1.16/-1.97 [dB], diff MSE Validation total/theta/cv: -0.399848/-0.399848/-0.495335 [dB]
# Optimal idx: 66 Optimal : tensor(14.5987) [dB]
# 67, MSE Training total/theta/omega: -5.31/-5.31/12.14 [dB], MSE Validation total/theta/omega :14.23/14.23/32.88 [dB]
# diff MSE Training total/theta/cv : -3.59/-3.59/-1.30 [dB], diff MSE Validation total/theta/cv: -0.369354/-0.369354/-0.450825 [dB]
# Optimal idx: 67 Optimal : tensor(14.2294) [dB]
# 68, MSE Training total/theta/omega: -4.06/-4.06/8.10 [dB], MSE Validation total/theta/omega :13.81/13.81/32.43 [dB]
# diff MSE Training total/theta/cv : 1.25/1.25/-4.04 [dB], diff MSE Validation total/theta/cv: -0.415484/-0.415484/-0.449387 [dB]
# Optimal idx: 68 Optimal : tensor(13.8139) [dB]
# 69, MSE Training total/theta/omega: -2.32/-2.32/14.18 [dB], MSE Validation total/theta/omega :13.47/13.47/32.09 [dB]
# diff MSE Training total/theta/cv : 1.74/1.74/6.08 [dB], diff MSE Validation total/theta/cv: -0.345986/-0.345986/-0.339088 [dB]
# Optimal idx: 69 Optimal : tensor(13.4679) [dB]
# 70, MSE Training total/theta/omega: -5.18/-5.18/11.71 [dB], MSE Validation total/theta/omega :12.94/12.94/31.44 [dB]
# diff MSE Training total/theta/cv : -2.86/-2.86/-2.47 [dB], diff MSE Validation total/theta/cv: -0.531941/-0.531941/-0.643000 [dB]
# Optimal idx: 70 Optimal : tensor(12.9360) [dB]
# 71, MSE Training total/theta/omega: -4.59/-4.59/10.80 [dB], MSE Validation total/theta/omega :12.58/12.58/31.03 [dB]
# diff MSE Training total/theta/cv : 0.59/0.59/-0.91 [dB], diff MSE Validation total/theta/cv: -0.359063/-0.359063/-0.414614 [dB]
# Optimal idx: 71 Optimal : tensor(12.5769) [dB]
# 72, MSE Training total/theta/omega: -6.18/-6.18/14.08 [dB], MSE Validation total/theta/omega :12.31/12.31/30.71 [dB]
# diff MSE Training total/theta/cv : -1.59/-1.59/3.28 [dB], diff MSE Validation total/theta/cv: -0.268161/-0.268161/-0.318493 [dB]
# Optimal idx: 72 Optimal : tensor(12.3087) [dB]
# 73, MSE Training total/theta/omega: -6.66/-6.66/10.39 [dB], MSE Validation total/theta/omega :11.96/11.96/30.35 [dB]
# diff MSE Training total/theta/cv : -0.48/-0.48/-3.70 [dB], diff MSE Validation total/theta/cv: -0.346806/-0.346806/-0.357250 [dB]
# Optimal idx: 73 Optimal : tensor(11.9619) [dB]
# 74, MSE Training total/theta/omega: -4.95/-4.95/14.84 [dB], MSE Validation total/theta/omega :11.57/11.57/29.96 [dB]
# diff MSE Training total/theta/cv : 1.71/1.71/4.45 [dB], diff MSE Validation total/theta/cv: -0.395634/-0.395634/-0.389135 [dB]
# Optimal idx: 74 Optimal : tensor(11.5663) [dB]
# 75, MSE Training total/theta/omega: -4.47/-4.47/11.02 [dB], MSE Validation total/theta/omega :11.27/11.27/29.69 [dB]
# diff MSE Training total/theta/cv : 0.48/0.48/-3.83 [dB], diff MSE Validation total/theta/cv: -0.295741/-0.295741/-0.274643 [dB]
# Optimal idx: 75 Optimal : tensor(11.2706) [dB]
# 76, MSE Training total/theta/omega: -9.52/-9.52/8.75 [dB], MSE Validation total/theta/omega :10.94/10.94/29.39 [dB]
# diff MSE Training total/theta/cv : -5.05/-5.05/-2.27 [dB], diff MSE Validation total/theta/cv: -0.327288/-0.327288/-0.302515 [dB]
# Optimal idx: 76 Optimal : tensor(10.9433) [dB]
# 77, MSE Training total/theta/omega: -9.86/-9.86/13.84 [dB], MSE Validation total/theta/omega :10.55/10.55/28.98 [dB]
# diff MSE Training total/theta/cv : -0.35/-0.35/5.09 [dB], diff MSE Validation total/theta/cv: -0.390409/-0.390409/-0.409849 [dB]
# Optimal idx: 77 Optimal : tensor(10.5529) [dB]
# 78, MSE Training total/theta/omega: -6.58/-6.58/12.30 [dB], MSE Validation total/theta/omega :10.28/10.28/28.71 [dB]
# diff MSE Training total/theta/cv : 3.28/3.28/-1.54 [dB], diff MSE Validation total/theta/cv: -0.269842/-0.269842/-0.268486 [dB]
# Optimal idx: 78 Optimal : tensor(10.2830) [dB]
# 79, MSE Training total/theta/omega: -6.44/-6.44/13.71 [dB], MSE Validation total/theta/omega :9.78/9.78/28.15 [dB]
# diff MSE Training total/theta/cv : 0.14/0.14/1.41 [dB], diff MSE Validation total/theta/cv: -0.505673/-0.505673/-0.563253 [dB]
# Optimal idx: 79 Optimal : tensor(9.7773) [dB]
# 80, MSE Training total/theta/omega: -3.75/-3.75/13.83 [dB], MSE Validation total/theta/omega :9.51/9.51/27.90 [dB]
# diff MSE Training total/theta/cv : 2.69/2.69/0.13 [dB], diff MSE Validation total/theta/cv: -0.271912/-0.271912/-0.249537 [dB]
# Optimal idx: 80 Optimal : tensor(9.5054) [dB]
# 81, MSE Training total/theta/omega: -6.23/-6.23/13.00 [dB], MSE Validation total/theta/omega :9.31/9.31/27.68 [dB]
# diff MSE Training total/theta/cv : -2.48/-2.48/-0.83 [dB], diff MSE Validation total/theta/cv: -0.195146/-0.195146/-0.213728 [dB]
# Optimal idx: 81 Optimal : tensor(9.3103) [dB]
# 82, MSE Training total/theta/omega: -4.75/-4.75/15.82 [dB], MSE Validation total/theta/omega :9.07/9.07/27.51 [dB]
# diff MSE Training total/theta/cv : 1.48/1.48/2.82 [dB], diff MSE Validation total/theta/cv: -0.238358/-0.238358/-0.171091 [dB]
# Optimal idx: 82 Optimal : tensor(9.0719) [dB]
# 83, MSE Training total/theta/omega: -7.02/-7.02/7.52 [dB], MSE Validation total/theta/omega :8.87/8.87/27.32 [dB]
# diff MSE Training total/theta/cv : -2.27/-2.27/-8.30 [dB], diff MSE Validation total/theta/cv: -0.203117/-0.203117/-0.193947 [dB]
# Optimal idx: 83 Optimal : tensor(8.8688) [dB]
# 84, MSE Training total/theta/omega: -6.26/-6.26/10.41 [dB], MSE Validation total/theta/omega :8.64/8.64/27.10 [dB]
# diff MSE Training total/theta/cv : 0.76/0.76/2.89 [dB], diff MSE Validation total/theta/cv: -0.229226/-0.229226/-0.212309 [dB]
# Optimal idx: 84 Optimal : tensor(8.6396) [dB]
# 85, MSE Training total/theta/omega: -7.02/-7.02/11.54 [dB], MSE Validation total/theta/omega :8.42/8.42/26.90 [dB]
# diff MSE Training total/theta/cv : -0.76/-0.76/1.13 [dB], diff MSE Validation total/theta/cv: -0.222363/-0.222363/-0.202980 [dB]
# Optimal idx: 85 Optimal : tensor(8.4172) [dB]
# 86, MSE Training total/theta/omega: -5.68/-5.68/13.95 [dB], MSE Validation total/theta/omega :8.24/8.24/26.73 [dB]
# diff MSE Training total/theta/cv : 1.34/1.34/2.41 [dB], diff MSE Validation total/theta/cv: -0.177435/-0.177435/-0.174381 [dB]
# Optimal idx: 86 Optimal : tensor(8.2398) [dB]
# 87, MSE Training total/theta/omega: -4.81/-4.81/13.22 [dB], MSE Validation total/theta/omega :7.98/7.98/26.47 [dB]
# diff MSE Training total/theta/cv : 0.87/0.87/-0.73 [dB], diff MSE Validation total/theta/cv: -0.261403/-0.261403/-0.261723 [dB]
# Optimal idx: 87 Optimal : tensor(7.9784) [dB]
# 88, MSE Training total/theta/omega: -3.42/-3.42/14.28 [dB], MSE Validation total/theta/omega :7.66/7.66/26.17 [dB]
# diff MSE Training total/theta/cv : 1.39/1.39/1.06 [dB], diff MSE Validation total/theta/cv: -0.320377/-0.320377/-0.293520 [dB]
# Optimal idx: 88 Optimal : tensor(7.6580) [dB]
# 89, MSE Training total/theta/omega: -5.62/-5.62/10.71 [dB], MSE Validation total/theta/omega :7.41/7.41/25.95 [dB]
# diff MSE Training total/theta/cv : -2.20/-2.20/-3.58 [dB], diff MSE Validation total/theta/cv: -0.251348/-0.251348/-0.225386 [dB]
# Optimal idx: 89 Optimal : tensor(7.4067) [dB]
# 90, MSE Training total/theta/omega: -5.63/-5.63/12.84 [dB], MSE Validation total/theta/omega :7.12/7.12/25.69 [dB]
# diff MSE Training total/theta/cv : -0.01/-0.01/2.13 [dB], diff MSE Validation total/theta/cv: -0.284669/-0.284669/-0.261196 [dB]
# Optimal idx: 90 Optimal : tensor(7.1220) [dB]
# 91, MSE Training total/theta/omega: -4.76/-4.76/10.27 [dB], MSE Validation total/theta/omega :6.85/6.85/25.47 [dB]
# diff MSE Training total/theta/cv : 0.86/0.86/-2.56 [dB], diff MSE Validation total/theta/cv: -0.269485/-0.269485/-0.213552 [dB]
# Optimal idx: 91 Optimal : tensor(6.8525) [dB]
# 92, MSE Training total/theta/omega: -4.36/-4.36/13.19 [dB], MSE Validation total/theta/omega :6.66/6.66/25.28 [dB]
# diff MSE Training total/theta/cv : 0.40/0.40/2.92 [dB], diff MSE Validation total/theta/cv: -0.187899/-0.187899/-0.191685 [dB]
# Optimal idx: 92 Optimal : tensor(6.6646) [dB]
# 93, MSE Training total/theta/omega: -5.86/-5.86/11.52 [dB], MSE Validation total/theta/omega :6.35/6.35/25.01 [dB]
# diff MSE Training total/theta/cv : -1.50/-1.50/-1.67 [dB], diff MSE Validation total/theta/cv: -0.318265/-0.318265/-0.272381 [dB]
# Optimal idx: 93 Optimal : tensor(6.3463) [dB]
# 94, MSE Training total/theta/omega: -6.35/-6.35/13.09 [dB], MSE Validation total/theta/omega :6.13/6.13/24.78 [dB]
# diff MSE Training total/theta/cv : -0.50/-0.50/1.57 [dB], diff MSE Validation total/theta/cv: -0.217657/-0.217657/-0.231718 [dB]
# Optimal idx: 94 Optimal : tensor(6.1287) [dB]
# 95, MSE Training total/theta/omega: -4.64/-4.64/12.54 [dB], MSE Validation total/theta/omega :5.92/5.92/24.56 [dB]
# diff MSE Training total/theta/cv : 1.71/1.71/-0.56 [dB], diff MSE Validation total/theta/cv: -0.204026/-0.204026/-0.213699 [dB]
# Optimal idx: 95 Optimal : tensor(5.9247) [dB]
# 96, MSE Training total/theta/omega: -4.46/-4.46/11.73 [dB], MSE Validation total/theta/omega :5.60/5.60/24.21 [dB]
# diff MSE Training total/theta/cv : 0.18/0.18/-0.80 [dB], diff MSE Validation total/theta/cv: -0.319726/-0.319726/-0.350140 [dB]
# Optimal idx: 96 Optimal : tensor(5.6049) [dB]
# 97, MSE Training total/theta/omega: -5.27/-5.27/8.77 [dB], MSE Validation total/theta/omega :4.84/4.84/23.33 [dB]
# diff MSE Training total/theta/cv : -0.81/-0.81/-2.97 [dB], diff MSE Validation total/theta/cv: -0.760318/-0.760318/-0.885910 [dB]
# Optimal idx: 97 Optimal : tensor(4.8446) [dB]
# 98, MSE Training total/theta/omega: -3.75/-3.75/12.63 [dB], MSE Validation total/theta/omega :4.70/4.70/23.19 [dB]
# diff MSE Training total/theta/cv : 1.52/1.52/3.87 [dB], diff MSE Validation total/theta/cv: -0.143230/-0.143230/-0.135616 [dB]
# Optimal idx: 98 Optimal : tensor(4.7014) [dB]
# 99, MSE Training total/theta/omega: -5.81/-5.81/10.87 [dB], MSE Validation total/theta/omega :4.57/4.57/23.05 [dB]
# diff MSE Training total/theta/cv : -2.06/-2.06/-1.76 [dB], diff MSE Validation total/theta/cv: -0.131305/-0.131305/-0.139088 [dB]
# Optimal idx: 99 Optimal : tensor(4.5701) [dB]
# 100, MSE Training total/theta/omega: -2.25/-2.25/14.29 [dB], MSE Validation total/theta/omega :4.29/4.29/22.74 [dB]
# diff MSE Training total/theta/cv : 3.56/3.56/3.42 [dB], diff MSE Validation total/theta/cv: -0.276644/-0.276644/-0.307468 [dB]
# Optimal idx: 100 Optimal : tensor(4.2934) [dB]
# 101, MSE Training total/theta/omega: -6.29/-6.29/13.75 [dB], MSE Validation total/theta/omega :4.13/4.13/22.57 [dB]
# diff MSE Training total/theta/cv : -4.03/-4.03/-0.55 [dB], diff MSE Validation total/theta/cv: -0.167281/-0.167281/-0.171196 [dB]
# Optimal idx: 101 Optimal : tensor(4.1262) [dB]
# 102, MSE Training total/theta/omega: -2.25/-2.25/13.15 [dB], MSE Validation total/theta/omega :3.99/3.99/22.42 [dB]
# diff MSE Training total/theta/cv : 4.04/4.04/-0.60 [dB], diff MSE Validation total/theta/cv: -0.133695/-0.133695/-0.150949 [dB]
# Optimal idx: 102 Optimal : tensor(3.9925) [dB]
# 103, MSE Training total/theta/omega: -3.58/-3.58/11.70 [dB], MSE Validation total/theta/omega :3.95/3.95/22.39 [dB]
# diff MSE Training total/theta/cv : -1.33/-1.33/-1.45 [dB], diff MSE Validation total/theta/cv: -0.038987/-0.038987/-0.035797 [dB]
# Optimal idx: 103 Optimal : tensor(3.9535) [dB]
# 104, MSE Training total/theta/omega: -7.70/-7.70/11.11 [dB], MSE Validation total/theta/omega :3.79/3.79/22.19 [dB]
# diff MSE Training total/theta/cv : -4.12/-4.12/-0.60 [dB], diff MSE Validation total/theta/cv: -0.167647/-0.167647/-0.194511 [dB]
# Optimal idx: 104 Optimal : tensor(3.7858) [dB]
# 105, MSE Training total/theta/omega: -5.11/-5.11/14.15 [dB], MSE Validation total/theta/omega :3.57/3.57/21.95 [dB]
# diff MSE Training total/theta/cv : 2.59/2.59/3.05 [dB], diff MSE Validation total/theta/cv: -0.218061/-0.218061/-0.241404 [dB]
# Optimal idx: 105 Optimal : tensor(3.5678) [dB]
# 106, MSE Training total/theta/omega: -6.47/-6.47/12.17 [dB], MSE Validation total/theta/omega :3.12/3.12/21.47 [dB]
# diff MSE Training total/theta/cv : -1.36/-1.36/-1.98 [dB], diff MSE Validation total/theta/cv: -0.450117/-0.450117/-0.484076 [dB]
# Optimal idx: 106 Optimal : tensor(3.1177) [dB]
# 107, MSE Training total/theta/omega: -4.60/-4.60/11.33 [dB], MSE Validation total/theta/omega :2.91/2.91/21.20 [dB]
# diff MSE Training total/theta/cv : 1.87/1.87/-0.83 [dB], diff MSE Validation total/theta/cv: -0.210428/-0.210428/-0.262583 [dB]
# Optimal idx: 107 Optimal : tensor(2.9072) [dB]
# 108, MSE Training total/theta/omega: -5.63/-5.63/12.05 [dB], MSE Validation total/theta/omega :2.74/2.74/20.94 [dB]
# diff MSE Training total/theta/cv : -1.03/-1.03/0.71 [dB], diff MSE Validation total/theta/cv: -0.166924/-0.166924/-0.267359 [dB]
# Optimal idx: 108 Optimal : tensor(2.7403) [dB]
# 109, MSE Training total/theta/omega: -5.51/-5.51/14.29 [dB], MSE Validation total/theta/omega :2.59/2.59/20.75 [dB]
# diff MSE Training total/theta/cv : 0.12/0.12/2.24 [dB], diff MSE Validation total/theta/cv: -0.146160/-0.146160/-0.188215 [dB]
# Optimal idx: 109 Optimal : tensor(2.5941) [dB]
# 110, MSE Training total/theta/omega: -5.49/-5.49/12.16 [dB], MSE Validation total/theta/omega :2.79/2.79/20.95 [dB]
# diff MSE Training total/theta/cv : 0.01/0.01/-2.12 [dB], diff MSE Validation total/theta/cv: 0.198726/0.198726/0.201900 [dB]
# Optimal idx: 109 Optimal : tensor(2.5941) [dB]
# 111, MSE Training total/theta/omega: -6.09/-6.09/11.98 [dB], MSE Validation total/theta/omega :2.67/2.67/20.80 [dB]
# diff MSE Training total/theta/cv : -0.60/-0.60/-0.18 [dB], diff MSE Validation total/theta/cv: -0.125359/-0.125359/-0.153757 [dB]
# Optimal idx: 109 Optimal : tensor(2.5941) [dB]
# 112, MSE Training total/theta/omega: -5.54/-5.54/12.61 [dB], MSE Validation total/theta/omega :2.50/2.50/20.61 [dB]
# diff MSE Training total/theta/cv : 0.55/0.55/0.63 [dB], diff MSE Validation total/theta/cv: -0.164719/-0.164719/-0.183125 [dB]
# Optimal idx: 112 Optimal : tensor(2.5028) [dB]
# 113, MSE Training total/theta/omega: -10.75/-10.75/11.04 [dB], MSE Validation total/theta/omega :2.39/2.39/20.49 [dB]
# diff MSE Training total/theta/cv : -5.21/-5.21/-1.57 [dB], diff MSE Validation total/theta/cv: -0.108521/-0.108521/-0.128206 [dB]
# Optimal idx: 113 Optimal : tensor(2.3943) [dB]
# 114, MSE Training total/theta/omega: -4.29/-4.29/13.00 [dB], MSE Validation total/theta/omega :2.28/2.28/20.35 [dB]
# diff MSE Training total/theta/cv : 6.47/6.47/1.96 [dB], diff MSE Validation total/theta/cv: -0.111096/-0.111096/-0.133636 [dB]
# Optimal idx: 114 Optimal : tensor(2.2832) [dB]
# 115, MSE Training total/theta/omega: -9.00/-9.00/9.46 [dB], MSE Validation total/theta/omega :2.20/2.20/20.28 [dB]
# diff MSE Training total/theta/cv : -4.71/-4.71/-3.53 [dB], diff MSE Validation total/theta/cv: -0.079223/-0.079223/-0.072918 [dB]
# Optimal idx: 115 Optimal : tensor(2.2039) [dB]
# 116, MSE Training total/theta/omega: -5.98/-5.98/10.90 [dB], MSE Validation total/theta/omega :2.16/2.16/20.22 [dB]
# diff MSE Training total/theta/cv : 3.02/3.02/1.43 [dB], diff MSE Validation total/theta/cv: -0.039561/-0.039561/-0.056980 [dB]
# Optimal idx: 116 Optimal : tensor(2.1644) [dB]
# 117, MSE Training total/theta/omega: -3.46/-3.46/12.35 [dB], MSE Validation total/theta/omega :2.08/2.08/20.12 [dB]
# diff MSE Training total/theta/cv : 2.52/2.52/1.46 [dB], diff MSE Validation total/theta/cv: -0.085327/-0.085327/-0.097244 [dB]
# Optimal idx: 117 Optimal : tensor(2.0791) [dB]
# 118, MSE Training total/theta/omega: -3.95/-3.95/12.01 [dB], MSE Validation total/theta/omega :1.76/1.76/19.75 [dB]
# diff MSE Training total/theta/cv : -0.49/-0.49/-0.34 [dB], diff MSE Validation total/theta/cv: -0.320524/-0.320524/-0.372984 [dB]
# Optimal idx: 118 Optimal : tensor(1.7585) [dB]
# 119, MSE Training total/theta/omega: -8.59/-8.59/12.52 [dB], MSE Validation total/theta/omega :1.69/1.69/19.69 [dB]
# diff MSE Training total/theta/cv : -4.64/-4.64/0.50 [dB], diff MSE Validation total/theta/cv: -0.067860/-0.067860/-0.064165 [dB]
# Optimal idx: 119 Optimal : tensor(1.6907) [dB]
# 120, MSE Training total/theta/omega: -4.93/-4.93/13.50 [dB], MSE Validation total/theta/omega :1.61/1.61/19.60 [dB]
# diff MSE Training total/theta/cv : 3.66/3.66/0.98 [dB], diff MSE Validation total/theta/cv: -0.080722/-0.080722/-0.083000 [dB]
# Optimal idx: 120 Optimal : tensor(1.6100) [dB]
# 121, MSE Training total/theta/omega: -8.05/-8.05/10.66 [dB], MSE Validation total/theta/omega :1.50/1.50/19.50 [dB]
# diff MSE Training total/theta/cv : -3.12/-3.12/-2.84 [dB], diff MSE Validation total/theta/cv: -0.111866/-0.111866/-0.103924 [dB]
# Optimal idx: 121 Optimal : tensor(1.4981) [dB]
# 122, MSE Training total/theta/omega: -4.89/-4.89/13.14 [dB], MSE Validation total/theta/omega :1.41/1.41/19.42 [dB]
# diff MSE Training total/theta/cv : 3.16/3.16/2.48 [dB], diff MSE Validation total/theta/cv: -0.086432/-0.086432/-0.083330 [dB]
# Optimal idx: 122 Optimal : tensor(1.4117) [dB]
# 123, MSE Training total/theta/omega: -6.47/-6.47/8.50 [dB], MSE Validation total/theta/omega :1.31/1.31/19.33 [dB]
# diff MSE Training total/theta/cv : -1.58/-1.58/-4.64 [dB], diff MSE Validation total/theta/cv: -0.099727/-0.099727/-0.086250 [dB]
# Optimal idx: 123 Optimal : tensor(1.3119) [dB]
# 124, MSE Training total/theta/omega: -6.51/-6.51/10.98 [dB], MSE Validation total/theta/omega :1.24/1.24/19.26 [dB]
# diff MSE Training total/theta/cv : -0.04/-0.04/2.48 [dB], diff MSE Validation total/theta/cv: -0.073726/-0.073726/-0.071707 [dB]
# Optimal idx: 124 Optimal : tensor(1.2382) [dB]
# 125, MSE Training total/theta/omega: -4.78/-4.78/11.22 [dB], MSE Validation total/theta/omega :1.16/1.16/19.19 [dB]
# diff MSE Training total/theta/cv : 1.73/1.73/0.24 [dB], diff MSE Validation total/theta/cv: -0.076382/-0.076382/-0.073408 [dB]
# Optimal idx: 125 Optimal : tensor(1.1618) [dB]
# 126, MSE Training total/theta/omega: -7.76/-7.76/10.96 [dB], MSE Validation total/theta/omega :1.11/1.11/19.13 [dB]
# diff MSE Training total/theta/cv : -2.98/-2.98/-0.26 [dB], diff MSE Validation total/theta/cv: -0.056138/-0.056138/-0.057825 [dB]
# Optimal idx: 126 Optimal : tensor(1.1057) [dB]
# 127, MSE Training total/theta/omega: -4.51/-4.51/11.24 [dB], MSE Validation total/theta/omega :1.01/1.01/19.01 [dB]
# diff MSE Training total/theta/cv : 3.25/3.25/0.28 [dB], diff MSE Validation total/theta/cv: -0.095469/-0.095469/-0.119658 [dB]
# Optimal idx: 127 Optimal : tensor(1.0102) [dB]
# 128, MSE Training total/theta/omega: -7.21/-7.21/9.72 [dB], MSE Validation total/theta/omega :0.94/0.94/18.93 [dB]
# diff MSE Training total/theta/cv : -2.71/-2.71/-1.51 [dB], diff MSE Validation total/theta/cv: -0.072053/-0.072053/-0.081177 [dB]
# Optimal idx: 128 Optimal : tensor(0.9382) [dB]
# 129, MSE Training total/theta/omega: -5.89/-5.89/10.74 [dB], MSE Validation total/theta/omega :0.89/0.89/18.88 [dB]
# diff MSE Training total/theta/cv : 1.32/1.32/1.02 [dB], diff MSE Validation total/theta/cv: -0.050445/-0.050445/-0.046608 [dB]
# Optimal idx: 129 Optimal : tensor(0.8877) [dB]
# 130, MSE Training total/theta/omega: -5.39/-5.39/10.65 [dB], MSE Validation total/theta/omega :0.80/0.80/18.80 [dB]
# diff MSE Training total/theta/cv : 0.50/0.50/-0.09 [dB], diff MSE Validation total/theta/cv: -0.089409/-0.089409/-0.076166 [dB]
# Optimal idx: 130 Optimal : tensor(0.7983) [dB]
# 131, MSE Training total/theta/omega: -4.56/-4.56/11.52 [dB], MSE Validation total/theta/omega :0.78/0.78/18.79 [dB]
# diff MSE Training total/theta/cv : 0.83/0.83/0.87 [dB], diff MSE Validation total/theta/cv: -0.014301/-0.014301/-0.011066 [dB]
# Optimal idx: 131 Optimal : tensor(0.7840) [dB]
# 132, MSE Training total/theta/omega: -5.55/-5.55/9.40 [dB], MSE Validation total/theta/omega :0.75/0.75/18.75 [dB]
# diff MSE Training total/theta/cv : -1.00/-1.00/-2.12 [dB], diff MSE Validation total/theta/cv: -0.037608/-0.037608/-0.043274 [dB]
# Optimal idx: 132 Optimal : tensor(0.7464) [dB]
# 133, MSE Training total/theta/omega: -7.52/-7.52/13.02 [dB], MSE Validation total/theta/omega :0.69/0.69/18.69 [dB]
# diff MSE Training total/theta/cv : -1.97/-1.97/3.61 [dB], diff MSE Validation total/theta/cv: -0.058857/-0.058857/-0.061604 [dB]
# Optimal idx: 133 Optimal : tensor(0.6875) [dB]
# 134, MSE Training total/theta/omega: -6.02/-6.02/12.44 [dB], MSE Validation total/theta/omega :0.65/0.65/18.64 [dB]
# diff MSE Training total/theta/cv : 1.50/1.50/-0.58 [dB], diff MSE Validation total/theta/cv: -0.041577/-0.041577/-0.048178 [dB]
# Optimal idx: 134 Optimal : tensor(0.6460) [dB]
# 135, MSE Training total/theta/omega: -8.79/-8.79/7.29 [dB], MSE Validation total/theta/omega :0.58/0.58/18.57 [dB]
# diff MSE Training total/theta/cv : -2.77/-2.77/-5.15 [dB], diff MSE Validation total/theta/cv: -0.067657/-0.067657/-0.068130 [dB]
# Optimal idx: 135 Optimal : tensor(0.5783) [dB]
# 136, MSE Training total/theta/omega: -5.23/-5.23/7.78 [dB], MSE Validation total/theta/omega :0.54/0.54/18.52 [dB]
# diff MSE Training total/theta/cv : 3.56/3.56/0.49 [dB], diff MSE Validation total/theta/cv: -0.041046/-0.041046/-0.048605 [dB]
# Optimal idx: 136 Optimal : tensor(0.5373) [dB]
# 137, MSE Training total/theta/omega: -5.84/-5.84/12.65 [dB], MSE Validation total/theta/omega :0.49/0.49/18.49 [dB]
# diff MSE Training total/theta/cv : -0.61/-0.61/4.87 [dB], diff MSE Validation total/theta/cv: -0.043889/-0.043889/-0.035856 [dB]
# Optimal idx: 137 Optimal : tensor(0.4934) [dB]
# 138, MSE Training total/theta/omega: -9.97/-9.97/8.35 [dB], MSE Validation total/theta/omega :0.44/0.44/18.43 [dB]
# diff MSE Training total/theta/cv : -4.13/-4.13/-4.31 [dB], diff MSE Validation total/theta/cv: -0.048401/-0.048401/-0.058504 [dB]
# Optimal idx: 138 Optimal : tensor(0.4450) [dB]
# 139, MSE Training total/theta/omega: -5.22/-5.22/12.06 [dB], MSE Validation total/theta/omega :0.41/0.41/18.39 [dB]
# diff MSE Training total/theta/cv : 4.75/4.75/3.72 [dB], diff MSE Validation total/theta/cv: -0.038297/-0.038297/-0.043003 [dB]
# Optimal idx: 139 Optimal : tensor(0.4067) [dB]
# 140, MSE Training total/theta/omega: -5.31/-5.31/10.75 [dB], MSE Validation total/theta/omega :0.37/0.37/18.34 [dB]
# diff MSE Training total/theta/cv : -0.09/-0.09/-1.32 [dB], diff MSE Validation total/theta/cv: -0.035067/-0.035067/-0.047268 [dB]
# Optimal idx: 140 Optimal : tensor(0.3716) [dB]
# 141, MSE Training total/theta/omega: -7.00/-7.00/10.57 [dB], MSE Validation total/theta/omega :0.34/0.34/18.31 [dB]
# diff MSE Training total/theta/cv : -1.70/-1.70/-0.18 [dB], diff MSE Validation total/theta/cv: -0.028310/-0.028310/-0.032526 [dB]
# Optimal idx: 141 Optimal : tensor(0.3433) [dB]
# 142, MSE Training total/theta/omega: -8.55/-8.55/10.37 [dB], MSE Validation total/theta/omega :0.30/0.30/18.25 [dB]
# diff MSE Training total/theta/cv : -1.54/-1.54/-0.20 [dB], diff MSE Validation total/theta/cv: -0.043899/-0.043899/-0.052441 [dB]
# Optimal idx: 142 Optimal : tensor(0.2994) [dB]
# 143, MSE Training total/theta/omega: -4.46/-4.46/10.37 [dB], MSE Validation total/theta/omega :0.26/0.26/18.20 [dB]
# diff MSE Training total/theta/cv : 4.09/4.09/0.00 [dB], diff MSE Validation total/theta/cv: -0.042612/-0.042612/-0.055935 [dB]
# Optimal idx: 143 Optimal : tensor(0.2568) [dB]
# 144, MSE Training total/theta/omega: -6.14/-6.14/9.63 [dB], MSE Validation total/theta/omega :0.21/0.21/18.13 [dB]
# diff MSE Training total/theta/cv : -1.68/-1.68/-0.74 [dB], diff MSE Validation total/theta/cv: -0.050985/-0.050985/-0.063976 [dB]
# Optimal idx: 144 Optimal : tensor(0.2058) [dB]
# 145, MSE Training total/theta/omega: -5.69/-5.69/11.51 [dB], MSE Validation total/theta/omega :0.13/0.13/18.04 [dB]
# diff MSE Training total/theta/cv : 0.45/0.45/1.88 [dB], diff MSE Validation total/theta/cv: -0.073563/-0.073563/-0.090622 [dB]
# Optimal idx: 145 Optimal : tensor(0.1322) [dB]
# 146, MSE Training total/theta/omega: -4.31/-4.31/12.31 [dB], MSE Validation total/theta/omega :0.05/0.05/17.91 [dB]
# diff MSE Training total/theta/cv : 1.37/1.37/0.81 [dB], diff MSE Validation total/theta/cv: -0.082597/-0.082597/-0.129824 [dB]
# Optimal idx: 146 Optimal : tensor(0.0496) [dB]
# 147, MSE Training total/theta/omega: -7.76/-7.76/9.70 [dB], MSE Validation total/theta/omega :0.00/0.00/17.85 [dB]
# diff MSE Training total/theta/cv : -3.45/-3.45/-2.61 [dB], diff MSE Validation total/theta/cv: -0.047225/-0.047225/-0.064232 [dB]
# Optimal idx: 147 Optimal : tensor(0.0024) [dB]
# 148, MSE Training total/theta/omega: -6.70/-6.70/9.87 [dB], MSE Validation total/theta/omega :0.01/0.01/17.87 [dB]
# diff MSE Training total/theta/cv : 1.06/1.06/0.17 [dB], diff MSE Validation total/theta/cv: 0.004026/0.004026/0.016886 [dB]
# Optimal idx: 147 Optimal : tensor(0.0024) [dB]
# 149, MSE Training total/theta/omega: -4.99/-4.99/12.08 [dB], MSE Validation total/theta/omega :-0.08/-0.08/17.79 [dB]
# diff MSE Training total/theta/cv : 1.71/1.71/2.21 [dB], diff MSE Validation total/theta/cv: -0.081607/-0.081607/-0.077938 [dB]
# Optimal idx: 149 Optimal : tensor(-0.0752) [dB]
# 150, MSE Training total/theta/omega: -6.13/-6.13/10.78 [dB], MSE Validation total/theta/omega :-0.15/-0.15/17.72 [dB]
# diff MSE Training total/theta/cv : -1.14/-1.14/-1.30 [dB], diff MSE Validation total/theta/cv: -0.076247/-0.076247/-0.069021 [dB]
# Optimal idx: 150 Optimal : tensor(-0.1514) [dB]
# 151, MSE Training total/theta/omega: -6.65/-6.65/10.09 [dB], MSE Validation total/theta/omega :-0.18/-0.18/17.69 [dB]
# diff MSE Training total/theta/cv : -0.53/-0.53/-0.68 [dB], diff MSE Validation total/theta/cv: -0.030428/-0.030428/-0.026409 [dB]
# Optimal idx: 151 Optimal : tensor(-0.1818) [dB]
# 152, MSE Training total/theta/omega: -3.86/-3.86/13.52 [dB], MSE Validation total/theta/omega :-0.23/-0.23/17.65 [dB]
# diff MSE Training total/theta/cv : 2.79/2.79/3.43 [dB], diff MSE Validation total/theta/cv: -0.044576/-0.044576/-0.039089 [dB]
# Optimal idx: 152 Optimal : tensor(-0.2264) [dB]
# 153, MSE Training total/theta/omega: -6.66/-6.66/10.33 [dB], MSE Validation total/theta/omega :-0.29/-0.29/17.57 [dB]
# diff MSE Training total/theta/cv : -2.80/-2.80/-3.19 [dB], diff MSE Validation total/theta/cv: -0.064083/-0.064083/-0.083876 [dB]
# Optimal idx: 153 Optimal : tensor(-0.2905) [dB]
# 154, MSE Training total/theta/omega: -4.15/-4.15/8.88 [dB], MSE Validation total/theta/omega :-0.33/-0.33/17.51 [dB]
# diff MSE Training total/theta/cv : 2.51/2.51/-1.45 [dB], diff MSE Validation total/theta/cv: -0.041905/-0.041905/-0.055220 [dB]
# Optimal idx: 154 Optimal : tensor(-0.3324) [dB]
# 155, MSE Training total/theta/omega: -6.80/-6.80/11.13 [dB], MSE Validation total/theta/omega :-0.41/-0.41/17.40 [dB]
# diff MSE Training total/theta/cv : -2.65/-2.65/2.25 [dB], diff MSE Validation total/theta/cv: -0.079312/-0.079312/-0.112194 [dB]
# Optimal idx: 155 Optimal : tensor(-0.4117) [dB]
# 156, MSE Training total/theta/omega: -4.29/-4.29/10.09 [dB], MSE Validation total/theta/omega :-0.44/-0.44/17.36 [dB]
# diff MSE Training total/theta/cv : 2.52/2.52/-1.04 [dB], diff MSE Validation total/theta/cv: -0.028089/-0.028089/-0.046186 [dB]
# Optimal idx: 156 Optimal : tensor(-0.4398) [dB]
# 157, MSE Training total/theta/omega: -9.65/-9.65/10.88 [dB], MSE Validation total/theta/omega :-0.50/-0.50/17.28 [dB]
# diff MSE Training total/theta/cv : -5.37/-5.37/0.78 [dB], diff MSE Validation total/theta/cv: -0.058647/-0.058647/-0.075068 [dB]
# Optimal idx: 157 Optimal : tensor(-0.4985) [dB]
# 158, MSE Training total/theta/omega: -5.80/-5.80/10.26 [dB], MSE Validation total/theta/omega :-0.52/-0.52/17.24 [dB]
# diff MSE Training total/theta/cv : 3.85/3.85/-0.61 [dB], diff MSE Validation total/theta/cv: -0.017958/-0.017958/-0.040718 [dB]
# Optimal idx: 158 Optimal : tensor(-0.5164) [dB]
# 159, MSE Training total/theta/omega: -7.22/-7.22/8.54 [dB], MSE Validation total/theta/omega :-0.59/-0.59/17.13 [dB]
# diff MSE Training total/theta/cv : -1.42/-1.42/-1.72 [dB], diff MSE Validation total/theta/cv: -0.077293/-0.077293/-0.107273 [dB]
# Optimal idx: 159 Optimal : tensor(-0.5937) [dB]
# 160, MSE Training total/theta/omega: -6.20/-6.20/11.84 [dB], MSE Validation total/theta/omega :-0.69/-0.69/16.99 [dB]
# diff MSE Training total/theta/cv : 1.02/1.02/3.30 [dB], diff MSE Validation total/theta/cv: -0.095970/-0.095970/-0.140100 [dB]
# Optimal idx: 160 Optimal : tensor(-0.6897) [dB]
# 161, MSE Training total/theta/omega: -6.19/-6.19/14.98 [dB], MSE Validation total/theta/omega :-0.70/-0.70/16.95 [dB]
# diff MSE Training total/theta/cv : 0.02/0.02/3.14 [dB], diff MSE Validation total/theta/cv: -0.007513/-0.007513/-0.044451 [dB]
# Optimal idx: 161 Optimal : tensor(-0.6972) [dB]
# 162, MSE Training total/theta/omega: -5.99/-5.99/9.53 [dB], MSE Validation total/theta/omega :-0.76/-0.76/16.86 [dB]
# diff MSE Training total/theta/cv : 0.19/0.19/-5.45 [dB], diff MSE Validation total/theta/cv: -0.062649/-0.062649/-0.093235 [dB]
# Optimal idx: 162 Optimal : tensor(-0.7598) [dB]
# 163, MSE Training total/theta/omega: -8.46/-8.46/10.32 [dB], MSE Validation total/theta/omega :-0.83/-0.83/16.73 [dB]
# diff MSE Training total/theta/cv : -2.47/-2.47/0.79 [dB], diff MSE Validation total/theta/cv: -0.072553/-0.072553/-0.123106 [dB]
# Optimal idx: 163 Optimal : tensor(-0.8324) [dB]
# 164, MSE Training total/theta/omega: -3.40/-3.40/12.79 [dB], MSE Validation total/theta/omega :-0.88/-0.88/16.65 [dB]
# ...
# Optimal idx: 290 Optimal : tensor(-2.9767) [dB]
# 291, MSE Training total/theta/omega: -8.53/-8.53/8.64 [dB], MSE Validation total/theta/omega :-2.98/-2.98/13.22 [dB]
# diff MSE Training total/theta/cv : 0.28/0.28/1.21 [dB], diff MSE Validation total/theta/cv: -0.006547/-0.006547/-0.006758 [dB]
# Optimal idx: 291 Optimal : tensor(-2.9832) [dB]
# 292, MSE Training total/theta/omega: -7.49/-7.49/6.43 [dB], MSE Validation total/theta/omega :-2.99/-2.99/13.21 [dB]
# diff MSE Training total/theta/cv : 1.04/1.04/-2.22 [dB], diff MSE Validation total/theta/cv: -0.005402/-0.005402/-0.003734 [dB]
# Optimal idx: 292 Optimal : tensor(-2.9886) [dB]
# 293, MSE Training total/theta/omega: -7.58/-7.58/9.98 [dB], MSE Validation total/theta/omega :-2.99/-2.99/13.21 [dB]
# diff MSE Training total/theta/cv : -0.09/-0.09/3.55 [dB], diff MSE Validation total/theta/cv: -0.004279/-0.004279/-0.003652 [dB]
# Optimal idx: 293 Optimal : tensor(-2.9929) [dB]
# 294, MSE Training total/theta/omega: -8.57/-8.57/9.77 [dB], MSE Validation total/theta/omega :-3.00/-3.00/13.20 [dB]
# diff MSE Training total/theta/cv : -0.99/-0.99/-0.20 [dB], diff MSE Validation total/theta/cv: -0.004399/-0.004399/-0.004585 [dB]
# Optimal idx: 294 Optimal : tensor(-2.9973) [dB]
# 295, MSE Training total/theta/omega: -8.44/-8.44/8.94 [dB], MSE Validation total/theta/omega :-3.00/-3.00/13.20 [dB]
# diff MSE Training total/theta/cv : 0.13/0.13/-0.83 [dB], diff MSE Validation total/theta/cv: -0.005046/-0.005046/-0.006208 [dB]
# Optimal idx: 295 Optimal : tensor(-3.0023) [dB]
# 296, MSE Training total/theta/omega: -5.64/-5.64/9.63 [dB], MSE Validation total/theta/omega :-3.01/-3.01/13.19 [dB]
# diff MSE Training total/theta/cv : 2.80/2.80/0.68 [dB], diff MSE Validation total/theta/cv: -0.004181/-0.004181/-0.004534 [dB]
# Optimal idx: 296 Optimal : tensor(-3.0065) [dB]
# 297, MSE Training total/theta/omega: -6.43/-6.43/8.83 [dB], MSE Validation total/theta/omega :-2.98/-2.98/13.22 [dB]
# diff MSE Training total/theta/cv : -0.79/-0.79/-0.80 [dB], diff MSE Validation total/theta/cv: 0.023544/0.023544/0.029135 [dB]
# Optimal idx: 296 Optimal : tensor(-3.0065) [dB]
# 298, MSE Training total/theta/omega: -7.99/-7.99/9.28 [dB], MSE Validation total/theta/omega :-2.99/-2.99/13.21 [dB]
# diff MSE Training total/theta/cv : -1.56/-1.56/0.45 [dB], diff MSE Validation total/theta/cv: -0.007037/-0.007037/-0.013779 [dB]
# Optimal idx: 296 Optimal : tensor(-3.0065) [dB]
# 299, MSE Training total/theta/omega: -5.52/-5.52/9.04 [dB], MSE Validation total/theta/omega :-3.00/-3.00/13.19 [dB]
# diff MSE Training total/theta/cv : 2.47/2.47/-0.24 [dB], diff MSE Validation total/theta/cv: -0.008734/-0.008734/-0.018309 [dB]
# Optimal idx: 296 Optimal : tensor(-3.0065) [dB]
# 300, MSE Training total/theta/omega: -8.20/-8.20/7.54 [dB], MSE Validation total/theta/omega :-3.01/-3.01/13.18 [dB]
# diff MSE Training total/theta/cv : -2.68/-2.68/-1.51 [dB], diff MSE Validation total/theta/cv: -0.007214/-0.007214/-0.011638 [dB]
# Optimal idx: 296 Optimal : tensor(-3.0065) [dB]
# 301, MSE Training total/theta/omega: -9.54/-9.54/8.57 [dB], MSE Validation total/theta/omega :-3.01/-3.01/13.17 [dB]
# diff MSE Training total/theta/cv : -1.34/-1.34/1.03 [dB], diff MSE Validation total/theta/cv: -0.003403/-0.003403/-0.005089 [dB]
# Optimal idx: 301 Optimal : tensor(-3.0094) [dB]
# 302, MSE Training total/theta/omega: -6.94/-6.94/8.21 [dB], MSE Validation total/theta/omega :-3.01/-3.01/13.17 [dB]
# diff MSE Training total/theta/cv : 2.59/2.59/-0.36 [dB], diff MSE Validation total/theta/cv: -0.005042/-0.005042/-0.005364 [dB]
# Optimal idx: 302 Optimal : tensor(-3.0144) [dB]
# 303, MSE Training total/theta/omega: -5.56/-5.56/9.84 [dB], MSE Validation total/theta/omega :-3.02/-3.02/13.16 [dB]
# diff MSE Training total/theta/cv : 1.39/1.39/1.63 [dB], diff MSE Validation total/theta/cv: -0.004641/-0.004641/-0.004581 [dB]
# Optimal idx: 303 Optimal : tensor(-3.0190) [dB]
# 304, MSE Training total/theta/omega: -7.70/-7.70/6.57 [dB], MSE Validation total/theta/omega :-3.02/-3.02/13.16 [dB]
# diff MSE Training total/theta/cv : -2.15/-2.15/-3.26 [dB], diff MSE Validation total/theta/cv: -0.004736/-0.004736/-0.003082 [dB]
# Optimal idx: 304 Optimal : tensor(-3.0238) [dB]
# 305, MSE Training total/theta/omega: -5.10/-5.10/10.20 [dB], MSE Validation total/theta/omega :-3.03/-3.03/13.16 [dB]
# diff MSE Training total/theta/cv : 2.60/2.60/3.62 [dB], diff MSE Validation total/theta/cv: -0.004876/-0.004876/-0.004361 [dB]
# Optimal idx: 305 Optimal : tensor(-3.0287) [dB]
# 306, MSE Training total/theta/omega: -7.76/-7.76/7.70 [dB], MSE Validation total/theta/omega :-3.03/-3.03/13.16 [dB]
# diff MSE Training total/theta/cv : -2.66/-2.66/-2.49 [dB], diff MSE Validation total/theta/cv: -0.003527/-0.003527/-0.000153 [dB]
# Optimal idx: 306 Optimal : tensor(-3.0322) [dB]
# 307, MSE Training total/theta/omega: -6.63/-6.63/9.57 [dB], MSE Validation total/theta/omega :-3.04/-3.04/13.15 [dB]
# diff MSE Training total/theta/cv : 1.12/1.12/1.87 [dB], diff MSE Validation total/theta/cv: -0.009596/-0.009596/-0.006385 [dB]
# Optimal idx: 307 Optimal : tensor(-3.0418) [dB]
# 308, MSE Training total/theta/omega: -6.71/-6.71/8.81 [dB], MSE Validation total/theta/omega :-3.05/-3.05/13.15 [dB]
# diff MSE Training total/theta/cv : -0.07/-0.07/-0.76 [dB], diff MSE Validation total/theta/cv: -0.004071/-0.004071/-0.000767 [dB]
# Optimal idx: 308 Optimal : tensor(-3.0459) [dB]
# 309, MSE Training total/theta/omega: -7.96/-7.96/8.41 [dB], MSE Validation total/theta/omega :-3.05/-3.05/13.15 [dB]
# diff MSE Training total/theta/cv : -1.26/-1.26/-0.40 [dB], diff MSE Validation total/theta/cv: -0.005374/-0.005374/-0.003717 [dB]
# Optimal idx: 309 Optimal : tensor(-3.0512) [dB]
# 310, MSE Training total/theta/omega: -7.11/-7.11/8.34 [dB], MSE Validation total/theta/omega :-3.05/-3.05/13.15 [dB]
# diff MSE Training total/theta/cv : 0.85/0.85/-0.07 [dB], diff MSE Validation total/theta/cv: -0.002693/-0.002693/0.003659 [dB]
# Optimal idx: 310 Optimal : tensor(-3.0539) [dB]
# 311, MSE Training total/theta/omega: -7.58/-7.58/6.56 [dB], MSE Validation total/theta/omega :-3.06/-3.06/13.15 [dB]
# diff MSE Training total/theta/cv : -0.47/-0.47/-1.78 [dB], diff MSE Validation total/theta/cv: -0.003173/-0.003173/0.000894 [dB]
# Optimal idx: 311 Optimal : tensor(-3.0571) [dB]
# 312, MSE Training total/theta/omega: -4.71/-4.71/8.64 [dB], MSE Validation total/theta/omega :-3.06/-3.06/13.15 [dB]
# diff MSE Training total/theta/cv : 2.87/2.87/2.08 [dB], diff MSE Validation total/theta/cv: -0.003255/-0.003255/0.001766 [dB]
# Optimal idx: 312 Optimal : tensor(-3.0603) [dB]
# 313, MSE Training total/theta/omega: -5.01/-5.01/12.75 [dB], MSE Validation total/theta/omega :-3.06/-3.06/13.16 [dB]
# diff MSE Training total/theta/cv : -0.30/-0.30/4.11 [dB], diff MSE Validation total/theta/cv: -0.002160/-0.002160/0.005580 [dB]
# Optimal idx: 313 Optimal : tensor(-3.0625) [dB]
# 314, MSE Training total/theta/omega: -5.52/-5.52/12.80 [dB], MSE Validation total/theta/omega :-3.07/-3.07/13.16 [dB]
# diff MSE Training total/theta/cv : -0.51/-0.51/0.05 [dB], diff MSE Validation total/theta/cv: -0.002727/-0.002727/0.003966 [dB]
# Optimal idx: 314 Optimal : tensor(-3.0652) [dB]
# 315, MSE Training total/theta/omega: -5.95/-5.95/10.33 [dB], MSE Validation total/theta/omega :-3.07/-3.07/13.16 [dB]
# diff MSE Training total/theta/cv : -0.43/-0.43/-2.47 [dB], diff MSE Validation total/theta/cv: -0.004540/-0.004540/0.003052 [dB]
# Optimal idx: 315 Optimal : tensor(-3.0698) [dB]
# 316, MSE Training total/theta/omega: -7.70/-7.70/10.56 [dB], MSE Validation total/theta/omega :-3.07/-3.07/13.17 [dB]
# diff MSE Training total/theta/cv : -1.75/-1.75/0.23 [dB], diff MSE Validation total/theta/cv: -0.003263/-0.003263/0.001408 [dB]
# Optimal idx: 316 Optimal : tensor(-3.0730) [dB]
# 317, MSE Training total/theta/omega: -9.86/-9.86/8.72 [dB], MSE Validation total/theta/omega :-3.08/-3.08/13.16 [dB]
# diff MSE Training total/theta/cv : -2.15/-2.15/-1.84 [dB], diff MSE Validation total/theta/cv: -0.006452/-0.006452/-0.007720 [dB]
# Optimal idx: 317 Optimal : tensor(-3.0795) [dB]
# 318, MSE Training total/theta/omega: -9.05/-9.05/9.34 [dB], MSE Validation total/theta/omega :-3.09/-3.09/13.15 [dB]
# diff MSE Training total/theta/cv : 0.81/0.81/0.62 [dB], diff MSE Validation total/theta/cv: -0.006920/-0.006920/-0.007687 [dB]
# Optimal idx: 318 Optimal : tensor(-3.0864) [dB]
# 319, MSE Training total/theta/omega: -9.26/-9.26/8.42 [dB], MSE Validation total/theta/omega :-3.09/-3.09/13.14 [dB]
# diff MSE Training total/theta/cv : -0.21/-0.21/-0.92 [dB], diff MSE Validation total/theta/cv: -0.007257/-0.007257/-0.008251 [dB]
# Optimal idx: 319 Optimal : tensor(-3.0937) [dB]
# 320, MSE Training total/theta/omega: -6.51/-6.51/10.88 [dB], MSE Validation total/theta/omega :-3.11/-3.11/13.13 [dB]
# diff MSE Training total/theta/cv : 2.75/2.75/2.45 [dB], diff MSE Validation total/theta/cv: -0.013576/-0.013576/-0.011353 [dB]
# Optimal idx: 320 Optimal : tensor(-3.1072) [dB]
# 321, MSE Training total/theta/omega: -6.18/-6.18/11.38 [dB], MSE Validation total/theta/omega :-3.11/-3.11/13.12 [dB]
# diff MSE Training total/theta/cv : 0.33/0.33/0.51 [dB], diff MSE Validation total/theta/cv: -0.005937/-0.005937/-0.006766 [dB]
# Optimal idx: 321 Optimal : tensor(-3.1132) [dB]
# 322, MSE Training total/theta/omega: -9.10/-9.10/7.68 [dB], MSE Validation total/theta/omega :-3.12/-3.12/13.12 [dB]
# diff MSE Training total/theta/cv : -2.92/-2.92/-3.70 [dB], diff MSE Validation total/theta/cv: -0.006107/-0.006107/-0.009055 [dB]
# Optimal idx: 322 Optimal : tensor(-3.1193) [dB]
# 323, MSE Training total/theta/omega: -9.13/-9.13/6.67 [dB], MSE Validation total/theta/omega :-3.12/-3.12/13.11 [dB]
# diff MSE Training total/theta/cv : -0.02/-0.02/-1.02 [dB], diff MSE Validation total/theta/cv: -0.005114/-0.005114/-0.005479 [dB]
# Optimal idx: 323 Optimal : tensor(-3.1244) [dB]
# 324, MSE Training total/theta/omega: -6.30/-6.30/9.80 [dB], MSE Validation total/theta/omega :-3.13/-3.13/13.11 [dB]
# diff MSE Training total/theta/cv : 2.83/2.83/3.13 [dB], diff MSE Validation total/theta/cv: -0.003763/-0.003763/-0.001993 [dB]
# Optimal idx: 324 Optimal : tensor(-3.1282) [dB]
# 325, MSE Training total/theta/omega: -6.29/-6.29/9.12 [dB], MSE Validation total/theta/omega :-3.13/-3.13/13.10 [dB]
# diff MSE Training total/theta/cv : 0.01/0.01/-0.67 [dB], diff MSE Validation total/theta/cv: -0.004907/-0.004907/-0.003933 [dB]
# Optimal idx: 325 Optimal : tensor(-3.1331) [dB]
# 326, MSE Training total/theta/omega: -6.78/-6.78/8.53 [dB], MSE Validation total/theta/omega :-3.14/-3.14/13.11 [dB]
# diff MSE Training total/theta/cv : -0.50/-0.50/-0.59 [dB], diff MSE Validation total/theta/cv: -0.003346/-0.003346/0.001760 [dB]
# Optimal idx: 326 Optimal : tensor(-3.1364) [dB]
# 327, MSE Training total/theta/omega: -6.47/-6.47/9.45 [dB], MSE Validation total/theta/omega :-3.14/-3.14/13.11 [dB]
# diff MSE Training total/theta/cv : 0.32/0.32/0.92 [dB], diff MSE Validation total/theta/cv: -0.002917/-0.002917/0.005016 [dB]
# Optimal idx: 327 Optimal : tensor(-3.1393) [dB]
# 328, MSE Training total/theta/omega: -7.17/-7.17/10.55 [dB], MSE Validation total/theta/omega :-3.14/-3.14/13.11 [dB]
# diff MSE Training total/theta/cv : -0.70/-0.70/1.10 [dB], diff MSE Validation total/theta/cv: -0.004230/-0.004230/-0.000987 [dB]
# Optimal idx: 328 Optimal : tensor(-3.1436) [dB]
# 329, MSE Training total/theta/omega: -10.04/-10.04/9.28 [dB], MSE Validation total/theta/omega :-3.15/-3.15/13.10 [dB]
# diff MSE Training total/theta/cv : -2.86/-2.86/-1.27 [dB], diff MSE Validation total/theta/cv: -0.007999/-0.007999/-0.007676 [dB]
# Optimal idx: 329 Optimal : tensor(-3.1516) [dB]
# 330, MSE Training total/theta/omega: -7.15/-7.15/7.70 [dB], MSE Validation total/theta/omega :-3.16/-3.16/13.10 [dB]
# diff MSE Training total/theta/cv : 2.88/2.88/-1.58 [dB], diff MSE Validation total/theta/cv: -0.004197/-0.004197/-0.004064 [dB]
# Optimal idx: 330 Optimal : tensor(-3.1558) [dB]
# 331, MSE Training total/theta/omega: -7.49/-7.49/8.28 [dB], MSE Validation total/theta/omega :-3.16/-3.16/13.09 [dB]
# diff MSE Training total/theta/cv : -0.34/-0.34/0.58 [dB], diff MSE Validation total/theta/cv: -0.008908/-0.008908/-0.010771 [dB]
# Optimal idx: 331 Optimal : tensor(-3.1647) [dB]
# 332, MSE Training total/theta/omega: -5.83/-5.83/8.61 [dB], MSE Validation total/theta/omega :-3.16/-3.16/13.09 [dB]
# diff MSE Training total/theta/cv : 1.66/1.66/0.33 [dB], diff MSE Validation total/theta/cv: 0.001207/0.001207/0.004699 [dB]
# Optimal idx: 331 Optimal : tensor(-3.1647) [dB]
# 333, MSE Training total/theta/omega: -8.39/-8.39/7.03 [dB], MSE Validation total/theta/omega :-3.17/-3.17/13.09 [dB]
# diff MSE Training total/theta/cv : -2.57/-2.57/-1.57 [dB], diff MSE Validation total/theta/cv: -0.001574/-0.001574/0.000700 [dB]
# Optimal idx: 333 Optimal : tensor(-3.1650) [dB]
# 334, MSE Training total/theta/omega: -9.58/-9.58/8.58 [dB], MSE Validation total/theta/omega :-3.17/-3.17/13.10 [dB]
# diff MSE Training total/theta/cv : -1.19/-1.19/1.55 [dB], diff MSE Validation total/theta/cv: -0.001500/-0.001500/0.006601 [dB]
# Optimal idx: 334 Optimal : tensor(-3.1665) [dB]
# 335, MSE Training total/theta/omega: -9.05/-9.05/9.49 [dB], MSE Validation total/theta/omega :-3.17/-3.17/13.10 [dB]
# diff MSE Training total/theta/cv : 0.53/0.53/0.91 [dB], diff MSE Validation total/theta/cv: -0.001327/-0.001327/0.000832 [dB]
# Optimal idx: 335 Optimal : tensor(-3.1679) [dB]
# 336, MSE Training total/theta/omega: -3.86/-3.86/9.53 [dB], MSE Validation total/theta/omega :-3.17/-3.17/13.10 [dB]
# diff MSE Training total/theta/cv : 5.19/5.19/0.03 [dB], diff MSE Validation total/theta/cv: -0.001563/-0.001563/0.002084 [dB]
# Optimal idx: 336 Optimal : tensor(-3.1694) [dB]
# 337, MSE Training total/theta/omega: -3.21/-3.21/11.34 [dB], MSE Validation total/theta/omega :-3.19/-3.19/13.09 [dB]
# diff MSE Training total/theta/cv : 0.65/0.65/1.82 [dB], diff MSE Validation total/theta/cv: -0.025420/-0.025420/-0.008898 [dB]
# Optimal idx: 337 Optimal : tensor(-3.1948) [dB]
# 338, MSE Training total/theta/omega: -6.26/-6.26/11.11 [dB], MSE Validation total/theta/omega :-3.20/-3.20/13.08 [dB]
# diff MSE Training total/theta/cv : -3.06/-3.06/-0.23 [dB], diff MSE Validation total/theta/cv: -0.006659/-0.006659/-0.011924 [dB]
# Optimal idx: 338 Optimal : tensor(-3.2015) [dB]
# 339, MSE Training total/theta/omega: -6.85/-6.85/10.00 [dB], MSE Validation total/theta/omega :-3.21/-3.21/13.07 [dB]
# diff MSE Training total/theta/cv : -0.59/-0.59/-1.12 [dB], diff MSE Validation total/theta/cv: -0.006782/-0.006782/-0.007560 [dB]
# Optimal idx: 339 Optimal : tensor(-3.2083) [dB]
# 340, MSE Training total/theta/omega: -6.45/-6.45/9.76 [dB], MSE Validation total/theta/omega :-3.19/-3.19/13.07 [dB]
# diff MSE Training total/theta/cv : 0.41/0.41/-0.23 [dB], diff MSE Validation total/theta/cv: 0.015549/0.015549/-0.008020 [dB]
# Optimal idx: 339 Optimal : tensor(-3.2083) [dB]
# 341, MSE Training total/theta/omega: -10.64/-10.64/9.04 [dB], MSE Validation total/theta/omega :-3.20/-3.20/13.05 [dB]
# diff MSE Training total/theta/cv : -4.19/-4.19/-0.72 [dB], diff MSE Validation total/theta/cv: -0.007585/-0.007585/-0.015275 [dB]
# Optimal idx: 339 Optimal : tensor(-3.2083) [dB]
# 342, MSE Training total/theta/omega: -5.18/-5.18/10.89 [dB], MSE Validation total/theta/omega :-3.21/-3.21/13.04 [dB]
# diff MSE Training total/theta/cv : 5.45/5.45/1.85 [dB], diff MSE Validation total/theta/cv: -0.007054/-0.007054/-0.014976 [dB]
# Optimal idx: 339 Optimal : tensor(-3.2083) [dB]
# 343, MSE Training total/theta/omega: -5.89/-5.89/8.30 [dB], MSE Validation total/theta/omega :-3.22/-3.22/13.02 [dB]
# diff MSE Training total/theta/cv : -0.70/-0.70/-2.59 [dB], diff MSE Validation total/theta/cv: -0.008236/-0.008236/-0.016886 [dB]
# Optimal idx: 343 Optimal : tensor(-3.2156) [dB]
# 344, MSE Training total/theta/omega: -5.12/-5.12/10.88 [dB], MSE Validation total/theta/omega :-3.23/-3.23/12.99 [dB]
# diff MSE Training total/theta/cv : 0.76/0.76/2.58 [dB], diff MSE Validation total/theta/cv: -0.010130/-0.010130/-0.024233 [dB]
# Optimal idx: 344 Optimal : tensor(-3.2257) [dB]

# %%
 #CONTINUE TRAINING 
r2s = [10]
q2s = [0, -10, -20]
q2s = [0]
q2s = list(map(lambda x: 10**(x/10), q2s))
v = 0
T_test = 400
T = 400
T_cv = 400
samples_train = 200 #size of training set
samples_cv = 200 #size of validation set
step=8


BATCH_SIZE_warm = 2
EPOCHS_warm = 0

EPOCHS = 30
BATCH_SIZE = 1
LR = 1e-3
WD = 1e-7
r2=10
for q2 in q2s:
  input_ = np.load(ROOT_PATH+f"Datasets/Pendulum/decimated_clean_data/pendulum_decimated_q2_{q2:.0e}_v_{v}.npz")
  target_ = input_
  r = np.sqrt(r2)
  q = np.sqrt(q2)
  train_input = torch.from_numpy(input_["training_set"][:samples_train, 0:1, :T]).to(dev) + torch.randn(input_["training_set"][:samples_train, 0:1, :T].shape) * r
  train_target = torch.from_numpy(target_["training_set"][:samples_train, :, :T]).float().to(dev)
  cv_input = torch.from_numpy(input_["validation_set"][:samples_cv, 0:1, :T_cv]).to(dev) + torch.randn(input_["validation_set"][:samples_cv, 0:1, :T_cv].shape) * r
  cv_target = torch.from_numpy(target_["validation_set"][:samples_cv, :, :T_cv]).float().to(dev)
  test_input = torch.from_numpy(input_["test_set"][:10, 0:1, :T_test]).to(dev) + torch.randn(input_["test_set"][:10, 0:1, :T_test].shape) * r
  test_target = torch.from_numpy(target_["test_set"][:10, :, :T_test]).float().to(dev)
  print(test_input.shape)
  h = h_partial
  m = 2  # DIMENSION OF STATE
  n = 1
  train_input = train_input.float().to(dev)
  cv_input = cv_input.float().to(dev)
  test_input = test_input.float().to(dev)
  cv_input = cv_input.float().to(dev)
  Q_true = q2 * torch.eye(m)
  R_true = r2 * torch.eye(n)
  Pipeline = torch.load(ROOT_PATH+f"Simulations_results/Pendulum/KalmanNet/constant_q2_experiment/tuning_experiments/experiment_T50_Tcv50_Ttest50_B200_LR0.002_WD1e-07_NT200_NCV200/models/pipeline_KNet.pt")
  #KNet_model = torch.load()
  Pipeline.folderName = ROOT_PATH +f"Simulations_results/Pendulum/KalmanNet/constant_q2_experiment/tuning_experiments/experiment_T50_Tcv50_Ttest50_B200_LR0.002_WD1e-07_NT200_NCV200/continuous_tra_T{T}_Tcv{T_cv}_Ttest{T_test}_B{BATCH_SIZE}_LR{LR}_WD{WD}_NT{samples_train}_NCV{samples_cv}/models/" 
  Pipeline.modelName = "KNet"
  folder = ROOT_PATH + f"Simulations_results/Pendulum/KalmanNet/constant_q2_experiment/tuning_experiments/experiment_T50_Tcv50_Ttest50_B200_LR0.002_WD1e-07_NT200_NCV200/continuous_tra_T{T}_Tcv{T_cv}_Ttest{T_test}_B{BATCH_SIZE}_LR{LR}_WD{WD}_NT{samples_train}_NCV{samples_cv}/losses"
  Pipeline.modelFileName = Pipeline.folderName + "model_" + Pipeline.modelName + ".pt"
  Pipeline.PipelineName = Pipeline.folderName + "pipeline_" + Pipeline.modelName + ".pt"
  os.makedirs(Pipeline.folderName +"/", exist_ok=True)
  os.makedirs(folder+"/", exist_ok=True)
  Pipeline.ssModel.T_test = T_test
  Pipeline.ssModel.T = T
  Pipeline.ssModel.T_cv = T_cv
  Pipeline.setTrainingParams(n_Epochs=EPOCHS, n_Batch=BATCH_SIZE, learningRate=LR, weightDecay=WD)
  Pipeline.NNTrain(train_input, train_target, cv_input, cv_target, save_model_wrt=0)

  
  [MSE_test_linear_arr_total, MSE_test_dB_avg_total, MSE_test_dB_std_total,
    MSE_test_linear_arr_theta, MSE_test_dB_avg_theta, MSE_test_dB_std_theta,
    MSE_test_linear_arr_omega, MSE_test_dB_avg_omega, MSE_test_dB_std_omega, x_out_array] = Pipeline.NNTest(test_input, test_target)

  cv_loss = Pipeline.MSE_cv_linear_epoch.detach().cpu().numpy()
  training_loss = Pipeline.MSE_train_linear_epoch.detach().cpu().numpy()
  

  np.savez(folder + f"/training_loss.npz", training_loss=training_loss, validation_loss=cv_loss, batch_size=BATCH_SIZE, epochs=EPOCHS, learning_rate=LR, weight_decay= WD)

  
  
  Pipeline.PlotTrain_KF()
  Pipeline.save()
  """
  #np.savez(folder+f"/test_loss.npz", MSE_linear_arr_total=MSE_test_linear_arr_total.cpu(), 
          MSE_std_total=MSE_test_dB_std_total.cpu(), MSE_db_avg_total=MSE_test_dB_avg_total.cpu(),
          MSE_linear_arr_theta=MSE_test_linear_arr_theta.cpu(), MSE_std_theta=MSE_test_dB_std_theta.cpu(), 
          MSE_db_avg_theta=MSE_test_dB_avg_theta.cpu(), MSE_linear_arr_omega=MSE_test_linear_arr_omega.cpu(), 
          MSE_std_omega=MSE_test_dB_std_omega.cpu(), MSE_db_avg_omega=MSE_test_dB_avg_omega.cpu(), 
          test_out=x_out_array.cpu(), batch_size=BATCH_SIZE, epochs=EPOCHS, learning_rate=LR, weight_decay=WD)

  """
# Out:
# torch.Size([10, 1, 400])
# 0, MSE Training total/theta/omega: 9.17/-4.62/12.09 [dB], MSE Validation total/theta/omega :21.88/23.36/19.60 [dB]
# Optimal idx: 0 Optimal : tensor(21.8783) [dB]
# 1, MSE Training total/theta/omega: 149.81/151.69/146.41 [dB], MSE Validation total/theta/omega :155.43/157.31/152.03 [dB]
# Optimal idx: 0 Optimal : tensor(21.8783) [dB]
# 2, MSE Training total/theta/omega: 52.16/55.03/40.04 [dB], MSE Validation total/theta/omega :54.41/57.28/42.21 [dB]
# diff MSE Training total/theta/cv : -97.65/-96.66/-106.37 [dB], diff MSE Validation total/theta/cv: -101.019836/-100.025513/-109.813957 [dB]
# Optimal idx: 0 Optimal : tensor(21.8783) [dB]
# 3, MSE Training total/theta/omega: 5.74/-7.05/8.63 [dB], MSE Validation total/theta/omega :5.92/-5.83/8.79 [dB]
# diff MSE Training total/theta/cv : -46.42/-62.09/-31.41 [dB], diff MSE Validation total/theta/cv: -48.481865/-63.113815/-33.426632 [dB]
# Optimal idx: 3 Optimal : tensor(5.9242) [dB]
# 4, MSE Training total/theta/omega: 2.80/-11.24/5.73 [dB], MSE Validation total/theta/omega :3.85/-8.58/6.74 [dB]
# diff MSE Training total/theta/cv : -2.93/-4.18/-2.91 [dB], diff MSE Validation total/theta/cv: -2.071446/-2.744886/-2.049956 [dB]
# Optimal idx: 4 Optimal : tensor(3.8528) [dB]
# 5, MSE Training total/theta/omega: -4.78/-7.52/-3.11 [dB], MSE Validation total/theta/omega :2.99/-7.22/5.79 [dB]
# diff MSE Training total/theta/cv : -7.58/3.72/-8.84 [dB], diff MSE Validation total/theta/cv: -0.864637/1.357117/-0.950847 [dB]
# Optimal idx: 5 Optimal : tensor(2.9881) [dB]
# 6, MSE Training total/theta/omega: 1.30/-7.44/4.01 [dB], MSE Validation total/theta/omega :2.56/-6.12/5.27 [dB]
# diff MSE Training total/theta/cv : 6.08/0.08/7.12 [dB], diff MSE Validation total/theta/cv: -0.423610/1.098554/-0.515855 [dB]
# Optimal idx: 6 Optimal : tensor(2.5645) [dB]
# 7, MSE Training total/theta/omega: 1.96/-3.45/4.30 [dB], MSE Validation total/theta/omega :2.32/-5.29/4.93 [dB]
# diff MSE Training total/theta/cv : 0.66/3.99/0.29 [dB], diff MSE Validation total/theta/cv: -0.248007/0.827860/-0.337568 [dB]
# Optimal idx: 7 Optimal : tensor(2.3165) [dB]
# 8, MSE Training total/theta/omega: -1.82/-3.94/-0.40 [dB], MSE Validation total/theta/omega :2.15/-4.65/4.68 [dB]
# diff MSE Training total/theta/cv : -3.78/-0.49/-4.69 [dB], diff MSE Validation total/theta/cv: -0.171341/0.638203/-0.256677 [dB]
# Optimal idx: 8 Optimal : tensor(2.1452) [dB]
# 9, MSE Training total/theta/omega: 0.89/-2.99/2.91 [dB], MSE Validation total/theta/omega :2.03/-4.15/4.49 [dB]
# diff MSE Training total/theta/cv : 2.71/0.95/3.31 [dB], diff MSE Validation total/theta/cv: -0.110996/0.503932/-0.188770 [dB]
# Optimal idx: 9 Optimal : tensor(2.0342) [dB]
# 10, MSE Training total/theta/omega: 4.81/-3.85/7.52 [dB], MSE Validation total/theta/omega :1.95/-3.74/4.33 [dB]
# diff MSE Training total/theta/cv : 3.92/-0.86/4.61 [dB], diff MSE Validation total/theta/cv: -0.083393/0.410206/-0.155533 [dB]
# Optimal idx: 10 Optimal : tensor(1.9508) [dB]
# 11, MSE Training total/theta/omega: 2.66/-2.98/5.04 [dB], MSE Validation total/theta/omega :1.85/-3.40/4.16 [dB]
# diff MSE Training total/theta/cv : -2.15/0.87/-2.48 [dB], diff MSE Validation total/theta/cv: -0.097597/0.341941/-0.170318 [dB]
# Optimal idx: 11 Optimal : tensor(1.8532) [dB]
# 12, MSE Training total/theta/omega: 7.96/-2.77/10.78 [dB], MSE Validation total/theta/omega :1.76/-3.11/4.00 [dB]
# diff MSE Training total/theta/cv : 5.30/0.20/5.75 [dB], diff MSE Validation total/theta/cv: -0.093145/0.287864/-0.163568 [dB]
# Optimal idx: 12 Optimal : tensor(1.7600) [dB]
# 13, MSE Training total/theta/omega: -0.10/-2.46/1.42 [dB], MSE Validation total/theta/omega :1.65/-2.86/3.81 [dB]
# diff MSE Training total/theta/cv : -8.06/0.31/-9.36 [dB], diff MSE Validation total/theta/cv: -0.111417/0.245659/-0.184466 [dB]
# Optimal idx: 13 Optimal : tensor(1.6486) [dB]
# 14, MSE Training total/theta/omega: -0.61/-2.70/0.79 [dB], MSE Validation total/theta/omega :1.55/-2.65/3.65 [dB]
# diff MSE Training total/theta/cv : -0.51/-0.24/-0.63 [dB], diff MSE Validation total/theta/cv: -0.095835/0.210910/-0.164683 [dB]
# Optimal idx: 14 Optimal : tensor(1.5528) [dB]
# 15, MSE Training total/theta/omega: 3.09/-0.83/5.12 [dB], MSE Validation total/theta/omega :1.48/-2.47/3.51 [dB]
# diff MSE Training total/theta/cv : 3.71/1.87/4.33 [dB], diff MSE Validation total/theta/cv: -0.073482/0.182344/-0.135669 [dB]
# Optimal idx: 15 Optimal : tensor(1.4793) [dB]
# 16, MSE Training total/theta/omega: 2.84/-1.49/4.96 [dB], MSE Validation total/theta/omega :1.39/-2.31/3.36 [dB]
# diff MSE Training total/theta/cv : -0.26/-0.66/-0.16 [dB], diff MSE Validation total/theta/cv: -0.084998/0.158265/-0.148541 [dB]
# Optimal idx: 16 Optimal : tensor(1.3943) [dB]
# 17, MSE Training total/theta/omega: 3.48/-1.57/5.75 [dB], MSE Validation total/theta/omega :1.31/-2.17/3.22 [dB]
# diff MSE Training total/theta/cv : 0.64/-0.07/0.79 [dB], diff MSE Validation total/theta/cv: -0.083013/0.137778/-0.144734 [dB]
# Optimal idx: 17 Optimal : tensor(1.3113) [dB]
# 18, MSE Training total/theta/omega: -0.03/-1.27/0.93 [dB], MSE Validation total/theta/omega :1.27/-2.05/3.12 [dB]
# diff MSE Training total/theta/cv : -3.51/0.30/-4.82 [dB], diff MSE Validation total/theta/cv: -0.045695/0.120857/-0.095001 [dB]
# Optimal idx: 18 Optimal : tensor(1.2656) [dB]
# 19, MSE Training total/theta/omega: -0.18/-2.12/1.15 [dB], MSE Validation total/theta/omega :1.23/-1.95/3.05 [dB]
# diff MSE Training total/theta/cv : -0.15/-0.86/0.22 [dB], diff MSE Validation total/theta/cv: -0.031675/0.106176/-0.074390 [dB]
# Optimal idx: 19 Optimal : tensor(1.2339) [dB]
# 20, MSE Training total/theta/omega: 3.75/0.13/5.70 [dB], MSE Validation total/theta/omega :1.21/-1.85/2.98 [dB]
# diff MSE Training total/theta/cv : 3.93/2.26/4.54 [dB], diff MSE Validation total/theta/cv: -0.028624/0.093102/-0.067854 [dB]
# Optimal idx: 20 Optimal : tensor(1.2053) [dB]
# 21, MSE Training total/theta/omega: 0.25/-1.04/1.24 [dB], MSE Validation total/theta/omega :1.17/-1.77/2.90 [dB]
# diff MSE Training total/theta/cv : -3.50/-1.18/-4.46 [dB], diff MSE Validation total/theta/cv: -0.038503/0.081772/-0.078727 [dB]
# Optimal idx: 21 Optimal : tensor(1.1668) [dB]
# 22, MSE Training total/theta/omega: -2.79/-3.67/-2.06 [dB], MSE Validation total/theta/omega :1.15/-1.70/2.85 [dB]
# diff MSE Training total/theta/cv : -3.04/-2.63/-3.30 [dB], diff MSE Validation total/theta/cv: -0.020891/0.072011/-0.052997 [dB]
# Optimal idx: 22 Optimal : tensor(1.1459) [dB]
# 23, MSE Training total/theta/omega: -0.77/-1.74/0.03 [dB], MSE Validation total/theta/omega :1.14/-1.64/2.82 [dB]
# diff MSE Training total/theta/cv : 2.02/1.93/2.08 [dB], diff MSE Validation total/theta/cv: -0.009188/0.063487/-0.034960 [dB]
# Optimal idx: 23 Optimal : tensor(1.1367) [dB]
# 24, MSE Training total/theta/omega: -0.81/-2.45/0.38 [dB], MSE Validation total/theta/omega :1.13/-1.58/2.79 [dB]
# diff MSE Training total/theta/cv : -0.04/-0.71/0.35 [dB], diff MSE Validation total/theta/cv: -0.002376/0.055276/-0.023243 [dB]
# Optimal idx: 24 Optimal : tensor(1.1343) [dB]
# 25, MSE Training total/theta/omega: -0.37/-1.68/0.64 [dB], MSE Validation total/theta/omega :1.14/-1.53/2.78 [dB]
# diff MSE Training total/theta/cv : 0.44/0.77/0.26 [dB], diff MSE Validation total/theta/cv: 0.002534/0.048675/-0.014438 [dB]
# Optimal idx: 24 Optimal : tensor(1.1343) [dB]
# 26, MSE Training total/theta/omega: 0.37/-0.79/1.29 [dB], MSE Validation total/theta/omega :1.14/-1.49/2.77 [dB]
# diff MSE Training total/theta/cv : 0.74/0.89/0.65 [dB], diff MSE Validation total/theta/cv: 0.006700/0.042373/-0.006593 [dB]
# Optimal idx: 24 Optimal : tensor(1.1343) [dB]
# 27, MSE Training total/theta/omega: 1.11/-0.99/2.52 [dB], MSE Validation total/theta/omega :1.16/-1.45/2.79 [dB]
# diff MSE Training total/theta/cv : 0.74/-0.19/1.23 [dB], diff MSE Validation total/theta/cv: 0.019832/0.036937/0.013406 [dB]
# Optimal idx: 24 Optimal : tensor(1.1343) [dB]
# 28, MSE Training total/theta/omega: -0.52/-3.86/1.35 [dB], MSE Validation total/theta/omega :1.18/-1.42/2.80 [dB]
# diff MSE Training total/theta/cv : -1.63/-2.87/-1.17 [dB], diff MSE Validation total/theta/cv: 0.019201/0.031906/0.014404 [dB]
# Optimal idx: 24 Optimal : tensor(1.1343) [dB]
# 29, MSE Training total/theta/omega: -1.24/-1.61/-0.89 [dB], MSE Validation total/theta/omega :1.21/-1.39/2.82 [dB]
# diff MSE Training total/theta/cv : -0.72/2.25/-2.24 [dB], diff MSE Validation total/theta/cv: 0.025209/0.027530/0.024332 [dB]
# Optimal idx: 24 Optimal : tensor(1.1343) [dB]
#  Test mse total/theta/omega: 0.7588328123092651/-1.7917759418487549/2.3550267219543457
#  Test STD total/theta/omega: 1.733996033668518/0.724332332611084/2.1324896812438965
# Inference Time: 3.5622520446777344

# %%
Pipeline.ssModel.T_test
# Out:
# 50

# %%
###CONSTANT NU EXPERIMENT###

m = 2
n = 1
h = h_partial
T = 400
T_test = 400
T_cv = 400
m1x_0 = torch.Tensor([[0.0], [0.0]]).to(dev)
m2x_0 = torch.eye(2)
EPOCHS = 200
BATCH_SIZE = 10
LR = 1e-3
WD = 1e-6
warm_up_T = 100
BATCH_SIZE_warm = 2
EPOCHS_warm = 30
warm_up_T_cv = 100

#writer = SummaryWriter(log_dir=ROOT_PATH+"KalmanNet", comment=f"EPOCHS_{EPOCHS}_LR_{LR}_BSIZ_{BATCH_SIZE}_WD_{WD}")


linewidth=0.5
markersize=2
title_size=7
ax_label_size=7

vs = [0, -10, -20]
#vs= [0]
r2s = [10, 2, 1, 0.5, 0.1, 0.01, 0.001, 0.0001]
#vs = [-20]
#r2s = [0.0001]
#r2s =[2, 1, 0.5]
#r2s = [0.1]
vs = [0]
#r2s = [0.01]
for v in vs:


  q2s = list(map(lambda x: x*(10**(v/10)), r2s))
  for r2, q2 in zip(r2s, q2s):
    print(f"Beginning with q2 {q2}, r2 {r2}.")
    today = date.today()
    now = datetime.datetime.now()
    strToday = today.strftime("%m.%d.%y")
    strNow = now.strftime("%H:%M:%S")
    strTime = strToday + "_" + strNow
    print("Current Time =", strTime)


    Q_true = q2 * torch.eye(m)
    R_true = r2 * torch.eye(n)

    
    


    q = np.sqrt(q2)
    r = np.sqrt(r2)
    input_ = np.load(ROOT_PATH+f"Datasets/Pendulum/decimated_noisy_data/pendulum_decimated_noisy_q2_{q2:.0e}_r2_{r2:.0e}_v{v}.npz")
    target_ = np.load(ROOT_PATH+f"Datasets/Pendulum/decimated_clean_data/pendulum_decimated_q2_{q2:.0e}_v_{v}.npz")
    train_input = torch.from_numpy(input_["training_set"][:1000, 0:1, :]).float().to(dev)
    train_target = torch.from_numpy(target_["training_set"][:1000, :, :]).float().to(dev)
    cv_input = torch.from_numpy(input_["validation_set"][:200, 0:1, :]).float().to(dev)
    cv_target = torch.from_numpy(target_["validation_set"][:200, ...]).float().to(dev)
    
    train_input_warm = torch.from_numpy(input_["training_set"][2000:2500, 0:1, :warm_up_T]).float().to(dev)
    train_target_warm = torch.from_numpy(target_["training_set"][2000:2500, :, :warm_up_T]).float().to(dev)
    cv_input_warm_up = torch.from_numpy(input_["validation_set"][500:550, 0:1, :warm_up_T_cv]).float().to(dev)
    cv_target_warm_up = torch.from_numpy(target_["validation_set"][500:550, :, :warm_up_T_cv]).float().to(dev)

    test_input = torch.from_numpy(input_["test_set"][:, 0:1, :]).float().to(dev)
    test_target = torch.from_numpy(target_["test_set"][:, :, :]).float().to(dev)
    print(train_input.shape, train_target.shape, cv_input.shape, cv_target.shape)


    #WARM UP PHASE
    print("WARM UP PHASE")
    sys_model = SystemModel(f, Q_true, h, R_true, warm_up_T, T_test, warm_up_T_cv)
    #sys_model.InitSequence(m1x_0, m2x_0)


    modelFolder = ROOT_PATH +f"Simulations_results/Pendulum/KalmanNet/partial_observation_lr_{LR}_WD_{WD}_BS_{BATCH_SIZE}_r2_{r2}_v_{v}/models_{q2:.0e}_r2_{r2:.0e}_v_{v}"
    folder = ROOT_PATH + f"Simulations_results/Pendulum/KalmanNet/partial_observation_lr_{LR}_WD_{WD}_BS_{BATCH_SIZE}_r2_{r2}_v_{v}"
    os.makedirs(modelFolder+"/", exist_ok=True)
    KNet_Pipeline = Pipeline_EKF(strTime, modelFolder, f"KNet")
    KNet_Pipeline.setssModel(sys_model)
    KNet_model = KalmanNetNN()
    KNet_model.Build(sys_model)
    KNet_Pipeline.setModel(KNet_model)
    KNet_Pipeline.setTrainingParams(n_Epochs=EPOCHS_warm, n_Batch=BATCH_SIZE_warm, learningRate=LR, weightDecay=WD)
    #KNet_Pipeline.NNTrain(train_input_warm, train_target_warm, cv_input_warm_up, cv_target_warm_up, save_model=False, early_stopping=False, true_init=1)
    KNet_Pipeline.NNTrain(train_input_warm, train_target_warm, cv_input_warm_up, cv_target_warm_up)
    print("ACTUAL TRAINING PHASE")
    #TRAINING PHASE
    sys_model = SystemModel(f, Q_true, h, R_true, T, T_test, T_cv)
    #sys_model.InitSequence(m1x_0, m2x_0)
    KNet_Pipeline.setssModel(sys_model)
    #KNet_model.InitSequence(sys_model.m1x_0, sys_model.T)
    #KNet_Pipeline.setModel(KNet_model)

    KNet_Pipeline.setTrainingParams(n_Epochs=EPOCHS, n_Batch=BATCH_SIZE, learningRate=LR, weightDecay=WD)
    #KNet_Pipeline.NNTrain(train_input, train_target, cv_input, cv_target, save_model=True, early_stopping=False, patience_early=20, true_init=1, patience_scheduler=15, scheduler_factor=0.5, threshold=0.1)
    KNet_Pipeline.NNTrain(train_input, train_target, cv_input, cv_target)
    
    cv_loss = KNet_Pipeline.MSE_cv_linear_epoch.cpu().numpy()
    training_loss = KNet_Pipeline.MSE_train_linear_epoch.cpu().numpy()
    

    np.savez(folder + f"/training_loss_q2_{q2:.0e}_r2_{r2:.0e}_v_{v}.npz", training_loss=training_loss, validation_loss=cv_loss, batch_size=BATCH_SIZE, epochs=EPOCHS, learning_rate=LR, weight_decay= WD)

    """
    [MSE_test_linear_arr_total, MSE_test_dB_avg_total, MSE_test_dB_std_total,
    MSE_test_linear_arr_theta, MSE_test_dB_avg_theta, MSE_test_dB_std_theta,
    MSE_test_linear_arr_omega, MSE_test_dB_avg_omega, MSE_test_dB_std_omega, x_out_array] = KNet_Pipeline.NNTest(test_input, test_target, true_init=1)
    """
    [MSE_test_linear_arr_total, MSE_test_dB_avg_total, MSE_test_dB_std_total,
    MSE_test_linear_arr_theta, MSE_test_dB_avg_theta, MSE_test_dB_std_theta,
    MSE_test_linear_arr_omega, MSE_test_dB_avg_omega, MSE_test_dB_std_omega, x_out_array] = KNet_Pipeline.NNTest(test_input, test_target)
    KNet_Pipeline.PlotTrain_KF()
    KNet_Pipeline.save()
    
    np.savez(folder+f"/test_{q2:.0e}_{r2:.0e}_v{v}.npz", MSE_linear_arr_total=MSE_test_linear_arr_total.cpu(), 
            MSE_std_total=MSE_test_dB_std_total.cpu(), MSE_db_avg_total=MSE_test_dB_avg_total.cpu(),
            MSE_linear_arr_theta=MSE_test_linear_arr_theta.cpu(), MSE_std_theta=MSE_test_dB_std_theta.cpu(), 
            MSE_db_avg_theta=MSE_test_dB_avg_theta.cpu(), MSE_linear_arr_omega=MSE_test_linear_arr_omega.cpu(), 
            MSE_std_omega=MSE_test_dB_std_omega.cpu(), MSE_db_avg_omega=MSE_test_dB_avg_omega.cpu(), 
            test_out=x_out_array.cpu(), batch_size=BATCH_SIZE, epochs=EPOCHS, learning_rate=LR, weight_decay=WD)
    """

    plt.plot([i for i in range(1, len(training_loss)+1)], 10*np.log10(training_loss), 'r-', label="training_loss", linewidth=linewidth, markersize=markersize)
    plt.plot([i for i in range(1, len(cv_loss)+1)], 10*np.log10(cv_loss), 'g-', label = "validation loss", linewidth=linewidth, markersize=markersize)
    plt.axhline(MSE_test_dB_avg_total, color='r', label="test loss", linewidth=linewidth)
    plt.xlabel("EPOCHS")
    plt.ylabel("MSE")
    plt.title(f"Training-Validation loss q^2: {q2}, r^2: {r2}, $\nu$: {v} dB ")
    plt.legend()
    plt.tight_layout()
    plt.savefig(folder + f"/loss_plot_q2_{q2:.0e}_r2_{r2:.0e}_v_{v}.png")
    plt.close()
  
    del KNet_Pipeline
    del KNet_model
    """
# Out:
# Beginning with q2 10.0, r2 10.
# Current Time = 06.07.22_08:59:58
# torch.Size([1000, 1, 400]) torch.Size([1000, 2, 400]) torch.Size([200, 1, 400]) torch.Size([200, 2, 400])
# WARM UP PHASE
# 0 MSE Training : tensor(15.7510) [dB] MSE Validation : tensor(14.4195) [dB]
# Optimal idx: 0 Optimal : tensor(14.4195) [dB]
# 1 MSE Training : tensor(15.5645) [dB] MSE Validation : tensor(14.1987) [dB]
# Optimal idx: 1 Optimal : tensor(14.1987) [dB]
# 2 MSE Training : tensor(7.7507) [dB] MSE Validation : tensor(9.0113) [dB]
# diff MSE Training : tensor(-7.8139) [dB] diff MSE Validation : tensor(-5.1874) [dB]
# Optimal idx: 2 Optimal : tensor(9.0113) [dB]
# ACTUAL TRAINING PHASE
# 0 MSE Training : tensor(26.6658) [dB] MSE Validation : tensor(32.3231) [dB]
# Optimal idx: 0 Optimal : tensor(32.3231) [dB]
# 1 MSE Training : tensor(11.6698) [dB] MSE Validation : tensor(15.6549) [dB]
# Optimal idx: 1 Optimal : tensor(15.6549) [dB]
# KNet-MSE Test: tensor(15.7338) [dB]
# KNet- STD Test: tensor(4.2768) [dB]
# Inference Time: 352.76881432533264
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Beginning with q2 2.0, r2 2.
# Current Time = 06.07.22_09:10:29
# torch.Size([1000, 1, 400]) torch.Size([1000, 2, 400]) torch.Size([200, 1, 400]) torch.Size([200, 2, 400])
# WARM UP PHASE
# 0 MSE Training : tensor(140.3594) [dB] MSE Validation : tensor(142.3202) [dB]
# Optimal idx: 0 Optimal : tensor(142.3202) [dB]
# 1 MSE Training : tensor(108.0328) [dB] MSE Validation : tensor(112.7335) [dB]
# Optimal idx: 1 Optimal : tensor(112.7335) [dB]
# 2 MSE Training : tensor(71.0900) [dB] MSE Validation : tensor(91.3892) [dB]
# diff MSE Training : tensor(-36.9428) [dB] diff MSE Validation : tensor(-21.3443) [dB]
# Optimal idx: 2 Optimal : tensor(91.3892) [dB]
# ACTUAL TRAINING PHASE
# 0 MSE Training : tensor(inf) [dB] MSE Validation : tensor(inf) [dB]
# Optimal idx: 0 Optimal : 1000 [dB]
# 1 MSE Training : tensor(nan) [dB] MSE Validation : tensor(nan) [dB]
# Optimal idx: 0 Optimal : 1000 [dB]
# KNet-MSE Test: tensor(inf) [dB]
# KNet- STD Test: tensor(nan) [dB]
# Inference Time: 350.6738557815552
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Beginning with q2 1.0, r2 1.
# Current Time = 06.07.22_09:20:50
# torch.Size([1000, 1, 400]) torch.Size([1000, 2, 400]) torch.Size([200, 1, 400]) torch.Size([200, 2, 400])
# WARM UP PHASE
# 0 MSE Training : tensor(-6.4688) [dB] MSE Validation : tensor(-2.4211) [dB]
# Optimal idx: 0 Optimal : tensor(-2.4211) [dB]
# 1 MSE Training : tensor(-13.5409) [dB] MSE Validation : tensor(-4.9874) [dB]
# Optimal idx: 1 Optimal : tensor(-4.9874) [dB]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-704e1da742f7> in <module>()
#      89     KNet_Pipeline.setTrainingParams(n_Epochs=EPOCHS_warm, n_Batch=BATCH_SIZE_warm, learningRate=LR, weightDecay=WD)
#      90     #KNet_Pipeline.NNTrain(train_input_warm, train_target_warm, cv_input_warm_up, cv_target_warm_up, save_model=False, early_stopping=False, true_init=1)
# ---> 91     KNet_Pipeline.NNTrain(train_input_warm, train_target_warm, cv_input_warm_up, cv_target_warm_up)
#      92     print("ACTUAL TRAINING PHASE")
#      93     #TRAINING PHASE
#
# /content/drive/MyDrive/KalmanNet_Visual/KalmanNet_VO/KNet_original_code/Pipeline_EKF_original_mod.py in NNTrain(self, train_input, train_target, cv_input, cv_target)
#      85                 x_out_cv = torch.empty(self.ssModel.m, self.ssModel.T-1)
#      86                 for t in range(0, self.ssModel.T-1):
# ---> 87                     x_out_cv[:, t] = self.model(y_cv[:, t])
#      88
#      89                 # Compute Training Loss
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/drive/MyDrive/KalmanNet_Visual/KalmanNet_VO/KNet_original_code/KalmanNet_nn.py in forward(self, y)
#     327
#     328
# --> 329         self.x_out = self.KNet_step(y)
#     330
#     331         return self.x_out
#
# /content/drive/MyDrive/KalmanNet_Visual/KalmanNet_VO/KNet_original_code/KalmanNet_nn.py in KNet_step(self, y)
#     215
#     216         # Compute Kalman Gain
# --> 217         self.step_KGain_est(y)
#     218
#     219         # Save KGain in array
#
# /content/drive/MyDrive/KalmanNet_Visual/KalmanNet_VO/KNet_original_code/KalmanNet_nn.py in step_KGain_est(self, y)
#     201
#     202         # Kalman Gain Network Step
# --> 203         KG = self.KGain_step(obs_diff, obs_innov_diff, fw_evol_diff, fw_update_diff)
#     204
#     205         # Reshape Kalman Gain to a Matrix
#
# /content/drive/MyDrive/KalmanNet_Visual/KalmanNet_VO/KNet_original_code/KalmanNet_nn.py in KGain_step(self, obs_diff, obs_innov_diff, fw_evol_diff, fw_update_diff)
#     278         # Sigma_GRU
#     279         in_Sigma = torch.cat((out_Q, out_FC6), 2)
# --> 280         out_Sigma, self.h_Sigma = self.GRU_Sigma(in_Sigma, self.h_Sigma)
#     281
#     282         # FC 1
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     938             hx = self.permute_hidden(hx, sorted_indices)
#     939
# --> 940         self.check_forward_args(input, hx, batch_sizes)
#     941         if batch_sizes is None:
#     942             result = _VF.gru(input, hx, self._flat_weights, self.bias, self.num_layers,
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py in check_forward_args(self, input, hidden, batch_sizes)
#     228     def check_forward_args(self, input: Tensor, hidden: Tensor, batch_sizes: Optional[Tensor]):
#     229         self.check_input(input, batch_sizes)
# --> 230         expected_hidden_size = self.get_expected_hidden_size(input, batch_sizes)
#     231
#     232         self.check_hidden_size(hidden, expected_hidden_size)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py in get_expected_hidden_size(self, input, batch_sizes)
#     211             mini_batch = int(batch_sizes[0])
#     212         else:
# --> 213             mini_batch = input.size(0) if self.batch_first else input.size(1)
#     214         num_directions = 2 if self.bidirectional else 1
#     215         if self.proj_size > 0:
#
# KeyboardInterrupt:

# %%
###CONSTANT Q2 EXPERIMENT###

m = 2
n = 1
h = h_partial
T = 50
T_test = 50
T_cv = 50
m1x_0 = torch.Tensor([[0.0], [0.0]]).to(dev)
m2x_0 = torch.eye(2)
EPOCHS = 2
BATCH_SIZE = 10
LR = 1e-4
WD = 1e-7
warm_up_T = 50
BATCH_SIZE_warm = 2
EPOCHS_warm = 2
warm_up_T_cv = 50
modelKnow = "partial"
#writer = SummaryWriter(log_dir=ROOT_PATH+"KalmanNet", comment=f"EPOCHS_{EPOCHS}_LR_{LR}_BSIZ_{BATCH_SIZE}_WD_{WD}")


linewidth=0.5
markersize=2
title_size=7
ax_label_size=7




r2s = [10, 2, 1, 0.5, 0.1, 0.01, 0.001, 0.0001]
r2s = [0.5, 0.1, 0.01, 0.001, 0.0001]
r2s = [10]
q2s = [0, -10, -20]
q2s = [0]
q2s = list(map(lambda x: 10**(x/10), q2s))
v = 0

for q2 in q2s:
  input_ = np.load(ROOT_PATH+f"Datasets/Pendulum/decimated_clean_data/pendulum_decimated_q2_{q2:.0e}_v_{v}.npz")
  target_ = input_
  for r2 in r2s:
    print(f"Evaluation for r2 {r2}, q2 {q2} \n")
    
    r = np.sqrt(r2)
    q = np.sqrt(q2)

    """
    if modelKnow == "full":
      input_test = torch.from_numpy(input_["test_set"][:, :, :]) + torch.randn(input_["test_set"][:, :, :].shape) * r
      target_test = torch.from_numpy(target_test_).float().to(dev)

      input_val = torch.from_numpy(input_["validation_set"][:200, :, :]) + torch.randn(input_["validation_set"][:200, :, :].shape) * r
      target_val = torch.from_numpy(target_val_).float().to(dev)
      h = h_full
      NL_m = 2  # DIMENSION OF STATE
      NL_n = 2

    if modelKnow == "nonlinear":
      input_test = input_["test_set"]
      target_test = torch.from_numpy(target_test_).float().to(dev)

      input_test = input_test[:, 0:1, :]
      input_test = np.sin(input_test) + np.random.randn(*input_test.shape) * r
      input_test = torch.from_numpy(input_test).float().to(dev)

      input_val = input_["validation_set"][:200, 0:1, ...]
      target_val = torch.from_numpy(target_val_).float().to(dev)

      input_val = np.sin(input_val) + np.random.randn(*input_val.shape) * r
      input_val = torch.from_numpy(input_val).float().to(dev)
      h = h_nonlinear
      NL_m = 2  # DIMENSION OF STATE
      NL_n = 1
    """

    if modelKnow == "partial":
      train_input = torch.from_numpy(input_["training_set"][:200, 0:1, :50]).to(dev) + torch.randn(input_["training_set"][:200, 0:1, :50].shape) * r
      train_target = torch.from_numpy(target_["training_set"][:200, :, :50]).float().to(dev)
      cv_input = torch.from_numpy(input_["validation_set"][:200, 0:1, :50]).to(dev) + torch.randn(input_["validation_set"][:200, 0:1, :50].shape) * r
      cv_target = torch.from_numpy(target_["validation_set"][:200, :, :50]).float().to(dev)
       
      train_input_warm_up = torch.from_numpy(input_["training_set"][2000:2200, 0:1, :warm_up_T]).to(dev) + torch.randn(input_["training_set"][2000:2200, 0:1, :warm_up_T].shape) * r
      train_target_warm_up = torch.from_numpy(target_["training_set"][2000:2200, :, :warm_up_T]).float().to(dev)
      cv_input_warm_up = torch.from_numpy(input_["validation_set"][500:550, 0:1, :warm_up_T_cv]).to(dev) + torch.randn(input_["validation_set"][500:550, 0:1, :warm_up_T_cv].shape) * r
      cv_target_warm_up = torch.from_numpy(target_["validation_set"][500:550, :, :warm_up_T_cv]).float().to(dev)

      test_input = torch.from_numpy(input_["test_set"][:, 0:1, :50]).to(dev) + torch.randn(input_["test_set"][:, 0:1, :50].shape) * r
      test_target = torch.from_numpy(target_["test_set"][:, :, :50]).float().to(dev)

      h = h_partial
      m = 2  # DIMENSION OF STATE
      n = 1

    train_input = train_input.float().to(dev)
    cv_input = cv_input.float().to(dev)
    train_input_warm_up = train_input_warm_up.float().to(dev)
    cv_input_warm_up = cv_input_warm_up.float().to(dev)
    test_input = test_input.float().to(dev)
    cv_input = cv_input.float().to(dev)


  
    print(f"Beginning with q2 {q2}, r2 {r2}.")
    today = date.today()
    now = datetime.datetime.now()
    strToday = today.strftime("%m.%d.%y")
    strNow = now.strftime("%H:%M:%S")
    strTime = strToday + "_" + strNow
    print("Current Time =", strTime)


    Q_true = q2 * torch.eye(m)
    R_true = r2 * torch.eye(n)

    #WARM UP PHASE
    print("WARM UP PHASE")
    sys_model = SystemModel(f, Q_true, h, R_true, warm_up_T, T_test, warm_up_T_cv)
    #sys_model.InitSequence(m1x_0, m2x_0)


    modelFolder = ROOT_PATH +f"Simulations_results/Pendulum/KalmanNet/constant_q2_experiment/experiment_{q2:.0e}_r2_{r2:.0e}_v_{v}_small/models"
    folder = ROOT_PATH + f"Simulations_results/Pendulum/KalmanNet/constant_q2_experiment/experiment_{q2:.0e}_r2_{r2:.0e}_v_{v}_small/losses"
    os.makedirs(modelFolder+"/", exist_ok=True)
    os.makedirs(folder+"/", exist_ok=True)
    KNet_Pipeline = Pipeline_EKF(strTime, modelFolder, f"KNet")
    KNet_Pipeline.setssModel(sys_model)
    KNet_model = KalmanNetNN()
    KNet_model.Build(sys_model)
    KNet_Pipeline.setModel(KNet_model)
    KNet_Pipeline.setTrainingParams(n_Epochs=EPOCHS_warm, n_Batch=BATCH_SIZE_warm, learningRate=LR, weightDecay=WD)
    #KNet_Pipeline.NNTrain(train_input_warm, train_target_warm, cv_input_warm_up, cv_target_warm_up, save_model=False, early_stopping=False, true_init=1)
    KNet_Pipeline.NNTrain(train_input_warm_up, train_target_warm_up, cv_input_warm_up, cv_target_warm_up)
    print("ACTUAL TRAINING PHASE")
    #TRAINING PHASE
    sys_model = SystemModel(f, Q_true, h, R_true, T, T_test, T_cv)
    #sys_model.InitSequence(m1x_0, m2x_0)
    KNet_Pipeline.setssModel(sys_model)
    #KNet_model.InitSequence(sys_model.m1x_0, sys_model.T)
    #KNet_Pipeline.setModel(KNet_model)

    KNet_Pipeline.setTrainingParams(n_Epochs=EPOCHS, n_Batch=BATCH_SIZE, learningRate=LR, weightDecay=WD)
    #KNet_Pipeline.NNTrain(train_input, train_target, cv_input, cv_target, save_model=True, early_stopping=False, patience_early=20, true_init=1, patience_scheduler=15, scheduler_factor=0.5, threshold=0.1)
    KNet_Pipeline.NNTrain(train_input, train_target, cv_input, cv_target)
    
    cv_loss = KNet_Pipeline.MSE_cv_linear_epoch.detach().cpu().numpy()
    training_loss = KNet_Pipeline.MSE_train_linear_epoch.detach().cpu().numpy()
    

    np.savez(folder + f"/training_loss.npz", training_loss=training_loss, validation_loss=cv_loss, batch_size=BATCH_SIZE, epochs=EPOCHS, learning_rate=LR, weight_decay= WD)

    """
    [MSE_test_linear_arr_total, MSE_test_dB_avg_total, MSE_test_dB_std_total,
    MSE_test_linear_arr_theta, MSE_test_dB_avg_theta, MSE_test_dB_std_theta,
    MSE_test_linear_arr_omega, MSE_test_dB_avg_omega, MSE_test_dB_std_omega, x_out_array] = KNet_Pipeline.NNTest(test_input, test_target, true_init=1)
    """
    [MSE_test_linear_arr_total, MSE_test_dB_avg_total, MSE_test_dB_std_total,
    MSE_test_linear_arr_theta, MSE_test_dB_avg_theta, MSE_test_dB_std_theta,
    MSE_test_linear_arr_omega, MSE_test_dB_avg_omega, MSE_test_dB_std_omega, x_out_array] = KNet_Pipeline.NNTest(test_input, test_target)
    KNet_Pipeline.PlotTrain_KF()
    KNet_Pipeline.save()
    
    np.savez(folder+f"/test_loss.npz", MSE_linear_arr_total=MSE_test_linear_arr_total.cpu(), 
            MSE_std_total=MSE_test_dB_std_total.cpu(), MSE_db_avg_total=MSE_test_dB_avg_total.cpu(),
            MSE_linear_arr_theta=MSE_test_linear_arr_theta.cpu(), MSE_std_theta=MSE_test_dB_std_theta.cpu(), 
            MSE_db_avg_theta=MSE_test_dB_avg_theta.cpu(), MSE_linear_arr_omega=MSE_test_linear_arr_omega.cpu(), 
            MSE_std_omega=MSE_test_dB_std_omega.cpu(), MSE_db_avg_omega=MSE_test_dB_avg_omega.cpu(), 
            test_out=x_out_array.cpu(), batch_size=BATCH_SIZE, epochs=EPOCHS, learning_rate=LR, weight_decay=WD)
    """

    plt.plot([i for i in range(1, len(training_loss)+1)], 10*np.log10(training_loss), 'r-', label="training_loss", linewidth=linewidth, markersize=markersize)
    plt.plot([i for i in range(1, len(cv_loss)+1)], 10*np.log10(cv_loss), 'g-', label = "validation loss", linewidth=linewidth, markersize=markersize)
    plt.axhline(MSE_test_dB_avg_total, color='r', label="test loss", linewidth=linewidth)
    plt.xlabel("EPOCHS")
    plt.ylabel("MSE")
    plt.title(f"Training-Validation loss q^2: {q2}, r^2: {r2}, $\nu$: {v} dB ")
    plt.legend()
    plt.tight_layout()
    plt.savefig(folder + f"/loss_plot_q2_{q2:.0e}_r2_{r2:.0e}_v_{v}.png")
    plt.close()
  
    del KNet_Pipeline
    del KNet_model
    """
# Out:
# Evaluation for r2 10, q2 1.0
#
# Beginning with q2 1.0, r2 10.
# Current Time = 06.10.22_13:19:58
# WARM UP PHASE
# 0, MSE Training total/theta/omega: 67.52/69.64/63.23 [dB], MSE Validation total/theta/omega :63.84/65.96/59.52 [dB]
# Optimal idx: 0 Optimal : tensor(63.8377) [dB]
# 1, MSE Training total/theta/omega: 66.89/69.04/62.42 [dB], MSE Validation total/theta/omega :62.27/64.41/57.84 [dB]
# Optimal idx: 1 Optimal : tensor(62.2654) [dB]
# ACTUAL TRAINING PHASE
# 0, MSE Training total/theta/omega: 60.34/62.46/56.05 [dB], MSE Validation total/theta/omega :60.00/62.17/55.48 [dB]
# Optimal idx: 0 Optimal : tensor(60.0039) [dB]
# 1, MSE Training total/theta/omega: 47.17/49.40/42.34 [dB], MSE Validation total/theta/omega :58.65/60.85/54.01 [dB]
# Optimal idx: 1 Optimal : tensor(58.6540) [dB]
# KNet-MSE Test: tensor(58.3866) [dB]
# KNet- STD Test: tensor(5.2523) [dB]
# Inference Time: 45.927889585494995

# %%
dev
# Out:
# device(type='cuda', index=0)

# %%
# Out:
# tensor([[0.0306, 0.0306],
#         [0.0481, 0.0481]], grad_fn=<SqueezeBackward0>)

# %%
out.shape
# Out:
# torch.Size([2, 2])

# %%
h_full
# Out:
# <function model.h_full>
